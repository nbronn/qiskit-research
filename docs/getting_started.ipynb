# %%
# This code is part of Qiskit.
#
# (C) Copyright IBM 2022.
#
# This code is licensed under the Apache License, Version 2.0. You may
# obtain a copy of this license in the LICENSE.txt file in the root directory
# of this source tree or at http://www.apache.org/licenses/LICENSE-2.0.
#
# Any modifications or derivative works of this code must retain this
# copyright notice, and modified files need to carry a notice indicating
# that they have been altered from the originals.

# %% [markdown]
# # Getting Started
#
# This notebook outlines the best operating practices for mapping a given quantum circuit to real IBM backends. The tools used within build on Qiskit yet not all are contained within this repository. This repository also contains custom transpiler passes that users may construct their own `PassManager`s from.

# %%
from qiskit import IBMQ, transpile
from qiskit.circuit import ClassicalRegister, Parameter, QuantumCircuit
from qiskit.opflow import PauliTrotterEvolution, Suzuki
from qiskit.providers.fake_provider import FakeMumbai

import numpy as np
import matplotlib.pyplot as plt
plt.style.use("default")

# %%
# IBMQ.load_account()
# provider = IBMQ.get_provider(hub="", group="", project="")

IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q-internal', group='deployed', project='default')
backend = provider.get_backend("ibm_auckland")
# backend = provider.get_backend("ibmq_qasm_simulator")

# %% [markdown]
# ## Problem: Quantum Simulation
#
# Video Companions:
# - ["Time Evolution with Qiskit Nature & Opflow"](https://www.youtube.com/watch?v=PY6PWondOeQ)
# - ["Hamiltonian Time Evolution - Part 1"](https://www.youtube.com/watch?v=1zrtUmXR7Ew)
# - ["Hamiltonian Time Evolution - Part 2"](https://www.youtube.com/watch?v=o_uRWJgX0uA)
#
# As an example, we'll use the problem statement from [this manuscript](https://arxiv.org/abs/2108.09197), the quantum simulation of an Ising model Hamiltonian:
# $$
# H = -J \sum_{\langle i,j \rangle} Z_i Z_j + h \sum_i X_i
# $$
# where $J$ is the exchange coupling between adjacent spins and $h$ is the transverse magnetic field. Here $X_i$ and $Z_j$ are the Pauli matrices acting on qubits $i$ and $j$, respectively. This model describes an interacting system of spins in a magnetic field, which is normally a nearest-neighbor interaction, in order to highlight the mapping of this problem to quantum hardware, we make it an all-to-all interaction. <br> <br>
#
# We will use tools from `qiskit.opflow` to generate the circuits needed for the simulation. The Hamiltonian $H$ is formed by instantiating `Parameter`s and building the interactions from the Pauli matrices `I`, `X`, and `Z` by concatenating them in tensor products ($\otimes$) represented in `opflow` by the caret symbol `^`. The formal solution to Schrödinger's equation is
# $$
# U = e^{-iHt},
# $$
# the *time-evolution unitary* corresponding to Hamiltonian evolution under $H$, and is found formally using the `.exp_i()` on an operator expression. <br>

# %%
from helper import ising_hamiltonian
num_spins = 4
JJ = Parameter("J")
hh = Parameter("h")
tt = Parameter("t")

U_ham = ising_hamiltonian(num_spins, JJ, hh, tt, connectivity='all-to-all')
print(U_ham)
# Out:
# e^(-i*1.0*t * SummedOp([
#   -1.0*J * (
#     1.0 * ZZII
#     + 1.0 * ZIZI
#     + 1.0 * ZIIZ
#     + 1.0 * IZZI
#     + 1.0 * IZIZ
#     + 1.0 * IIZZ
#   ),
#   1.0*h * (
#     1.0 * XIII
#     + 1.0 * IXII
#     + 1.0 * IIXI
#     + 1.0 * IIIX
#   )
# ]))

# %% [markdown]
# ## Converting Operators to Circuits
#
# The `qiskit.opflow` module contains methods to convert the time-evolved operators (`EvolvedOp`s) to circuits. One common method is the Suzuki-Trotter decomposition, in which the total evolution time $t$ is broken into `num_steps` $N$. By choosing the second-order of the `PauliTrotterEvolution`, we create a circuit that acts like our unitary to second order $\mathcal{O}((t/N)^2)$.
#
# Practically, since many of the following transpilation steps are computationally intensive, it may make sense to break up your circuit into smaller subcircuits, and then combine them together to get the final circuit. This is naturally acheived for Trotterized algorithms, since `reps` here just repeats the same circuit `num_steps` times, hence we just set `num_steps=1` and the resulting circuits can be combined into as many steps as desired later.

# %%
num_steps = 1
trot_circ = (
    PauliTrotterEvolution(trotter_mode=Suzuki(order=1, reps=num_steps))
    .convert(U_ham)
    .to_circuit()
)
# trot_circ.draw("mpl")
# Out:
# Evolved Hamiltonian is not composed of only Paulis, converting to Pauli representation, which can be expensive.

# %% [markdown]
# ## Qubit Routing to Underlying Topology
#
# Video Companion: ["Nick Knows - Routing"](https://www.youtube.com/watch?v=jHx7oZfI7jw&list=PLOFEBzvs-VvodTtg75jH3t2levcnVlrkk&index=5) <br>
#
# In general problems must respect the layout of the actual quantum hardware. Due to limited connectivity, this often entails doing SWAP operations to move quantum information around. SWAPs are costly in the sense they consist of three `CX`s. The Qiskit transpiler with `optimization_level=3` uses the [SABRE SWAP method](https://arxiv.org/abs/1809.02573), which is efficient, however stochastic, since the SWAP-mapping problem is NP-hard. Here we do it several time and take the solution with the lowest CNOT count. This operation serves only to minimize the number of SWAPs in the transpiled circuits, and is not aware of noise on the underlying qubits. That is considered in a following step.

# %%
num_tries = 10
trot_circ_ts = transpile(
    [trot_circ] * num_tries, backend, optimization_level=3, seed_transpiler=12345
)
cx_counts = [trot_circ_ts[idx].count_ops()["cx"] for idx in range(num_tries)]
print(cx_counts)
# Out:
# [15, 15, 15, 15, 15, 15, 15, 15, 15, 15]

# %%
best_idx = np.argmin(cx_counts)
trot_circ_t = trot_circ_ts[best_idx]

# %% [markdown]
# ## Noise-aware Layout
#
# Video Companion: ["Nick Knows - Layout"](https://www.youtube.com/watch?v=qcFp90vbc6U&list=PLOFEBzvs-VvodTtg75jH3t2levcnVlrkk&index=6) <br>
#
# Now that we have a SWAP-mapped optimal circuit, we consider the layouts on the actual quantum backend. These layouts are found by the VF2 subgraph isomorphism algorithm, which is very fast. Since the transpiler mapped the circuit to physical qubits, we must first "deflate" the circuits with `deflate_circuit` (which removes idle qubits), finds the layouts with `matching_layouts`, then scores those layouts due to error rates, which are calculated by a cost function that may be specified by the user, see [`mapomatic`](https://github.com/Qiskit-Partners/mapomatic) documentation for how. The default cost function includes errors determined for each qubit gates and measurements, although not decoherence/relaxation caused by idle time, producing an *infidelity score* where the lowest number is the preferred layout.

# %%
from mapomatic import deflate_circuit, evaluate_layouts, matching_layouts
from qiskit_research.utils.pulse_scaling import get_ecr_pairs_from_backend

coupling_map = get_ecr_pairs_from_backend(backend)

trot_circ_def = deflate_circuit(trot_circ_t)
layouts = matching_layouts(trot_circ_def, coupling_map)
scored_layouts = evaluate_layouts(
    trot_circ_def, layouts, backend
)  # cost_function = cost_func
print(scored_layouts)
# Out:
# [([16, 14, 11, 8], 0.0978971180335847), ([24, 25, 22, 19], 0.1013625451711353), ([11, 14, 16, 19], 0.10193835020354225), ([20, 19, 16, 14], 0.10433274729080133), ([14, 16, 19, 20], 0.10494782773892897), ([8, 11, 14, 16], 0.1053839845013762), ([26, 25, 22, 19], 0.10577259379064785), ([9, 8, 11, 14], 0.10688082572699487), ([14, 11, 8, 9], 0.10793220135141635), ([19, 16, 14, 11], 0.10948209873252523), ([20, 19, 22, 25], 0.11167793552786565), ([25, 22, 19, 20], 0.115542773120891), ([19, 22, 25, 24], 0.11584716578613152), ([19, 22, 25, 26], 0.11777116111078989), ([14, 16, 19, 22], 0.1187952382961055), ([25, 22, 19, 16], 0.12686932721009203), ([22, 19, 16, 14], 0.13210768917165094), ([16, 19, 22, 25], 0.1347500464485053), ([26, 25, 24, 23], 0.16610199249280988), ([22, 25, 24, 23], 0.16839627141171554), ([23, 24, 25, 26], 0.20392370597133258), ([23, 24, 25, 22], 0.20487679973499828), ([25, 24, 23, 21], 0.269598931621837), ([17, 18, 21, 23], 0.273771844028427), ([23, 21, 18, 17], 0.3019357622654695), ([21, 23, 24, 25], 0.32551775909488057), ([18, 21, 23, 24], 0.34174703662999883), ([24, 23, 21, 18], 0.3574998007235103), ([10, 12, 15, 18], 1.0), ([13, 12, 15, 18], 1.0), ([18, 15, 12, 10], 1.0), ([18, 15, 12, 13], 1.0), ([12, 15, 18, 21], 1.0), ([12, 15, 18, 17], 1.0), ([21, 18, 15, 12], 1.0), ([17, 18, 15, 12], 1.0), ([15, 18, 21, 23], 1.0), ([23, 21, 18, 15], 1.0)]

# %% [markdown]
# ## Pulse Scaling
#
# Video Companion: ["Nick Knows - Pulse Scaling"](https://www.youtube.com/watch?v=xdRgKC1AMl8&list=PLOFEBzvs-VvodTtg75jH3t2levcnVlrkk&index=7) <br>
#
# For certain problems, in particular Trotterized quantum simulation problems, or other algorithms that require small angles of rotation in the two-qubit Hilbert space, it is more efficient to implement operations in terms of pulses extracted from the CNOT gate. Basically, a CNOT gate is *locally-equivalent* to an $R_{ZX}(\pi/2)$ rotation, meaning it is built from that and single-qubit rotations, as can be seen from the following code:

# %%
# TODO: check out Weyl decomp stuff

qc = QuantumCircuit(2)
qc.cx(0, 1)
qc_rzx = transpile(qc, basis_gates=["sx", "rz", "rzx"])

fig, (ax1, ax2) = plt.subplots(1, 2)
qc.draw("mpl", ax=ax1)
qc_rzx.draw("mpl", ax=ax2)

# %% [markdown]
# The `RZXGate` is very similar to the native two-qubit interation called [echoed cross resonance](https://arxiv.org/abs/1603.04821) which is used to create entanglement on IBM backends. In particular, many two-qubit interactions for quantum simulation, such as the $ZZ$-interaction of our Ising Hamiltonian, can be more efficiently represented (in terms of error) by $R_{ZX}(\theta)$ rotations, which are automatically broken into scaled echoed cross resonance `secr` gates unless `unroll_rzx_to_ecr` is set to `False`.

# %%
from qiskit_research.utils.convenience import scale_cr_pulses

theta = Parameter("$\\theta$")

qc = QuantumCircuit(2)
qc.rzz(theta, 0, 1)
qc_cx = transpile(qc, basis_gates=["rz", "sx", "cx"])
qc_rzx = scale_cr_pulses(qc_cx, backend)  # unroll_rzx_to_ecr = True, param_bind = {}

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 6))
qc.draw("mpl", ax=ax1)
qc_cx.draw("mpl", ax=ax2)
qc_rzx.draw("mpl", ax=ax3)
ax2.set_title("These are all equivalent circuits")
# Out:
# Text(0.5, 1.0, 'These are all equivalent circuits')

# %% [markdown]
# When we are implementing two-qubit rotation angles $\theta$ less than $\pi/2$, we can more efficiently express these interaction in terms of $R_{ZX}(\theta)$ rotations and directly build them from scaled echoed cross resonance (`secr`($\theta$)) pulses obtained from the backend, as detailed in [this manuscript](http://arxiv.org/abs/2012.11660). This method first uses a greedy algorithm called [template opimization](http://arxiv.org/abs/1909.05270) to identify parts of the circuit that can be substituted by $R_{ZX}$ rotations. If parameters are passed to the method via `param_bind`, it will bind them to the circuit and attach the necessary pulse gates for implementing the $R_{ZX}$ rotations (otherwise they can be bound and scaled later with `attach_cr_pulses`). Below we will do them separately, because we will attach a series of `Parameter`s as a function of time, and it is more efficient to do the template optimization step once since it is greedy and attaching the pulse schedules in quick.

# %%
# my_layout = scored_layouts[0][0]  # the layout with the lowest score (i.e., error)
my_layout = [8, 11, 14, 16] # debugging timing problem on 
trot_circ_sca = scale_cr_pulses(
    transpile(trot_circ_def, initial_layout=my_layout), 
    # transpile(transpile(trot_circ, basis_gates=['rx', 'rz', 'cx']), initial_layout=[0,1,2,3]), 
    backend,
    unroll_rzx_to_ecr=False
)
trot_circ_sca.draw("mpl", idle_wires=False)

# %%
from helper import build_ising_circuits

num_trotter_steps = 5 # 5 value from manuscript
num_time_steps = 30
stop_time = 3 # 10
t_range = np.linspace(0.1, stop_time, num_time_steps)  # values from manuscript
param_bind = {JJ: 0.5236, hh: 1.0}  # values from manuscript

circs = build_ising_circuits(trot_circ_sca, backend, num_trotter_steps, my_layout, param_bind, t_range)
# circs = build_ising_circuits(transpile(trot_circ_sca), backend, num_trotter_steps, [0, 1, 2, 3], param_bind, t_range)

# %%
circs[-1].draw('mpl', idle_wires=False)

# %% [markdown]
# ## Pauli Twirling
#
# Video Companion: ["Nick Knows - Pauli Twirling"](https://www.youtube.com/watch?v=4MLHvmmpSQ8&list=PLOFEBzvs-VvodTtg75jH3t2levcnVlrkk&index=8) <br>
#
# Pauli twirling is a form of randomized compiling that inserts pairs of Pauli gates (`I`, `X`, `Y`, `Z`) before and after entangling gates such that the overall unitary is the same, but the way it is implemented is different. This has the effect of turning coherent errors into stochastic errors, which can then be elimated by sufficient averaging. This is done a number of times (`num_twirled_circuits`) for the benefit of averaging. **Note:** we are probably using an insufficient basis set to currently cancel all errors.

# %%
# from qiskit_research.utils.convenience import add_pauli_twirls
# # TODO: check that we have adequate set of Paulis to twirl over

# num_twirls = 8
# # this returns a circuit with shape len(circs) x num_twirled_circuits
# twirled_circs = add_pauli_twirls(
#     circs, num_twirled_circuits=num_twirls, seed=12345
# )  # transpile_added_paulis = False

# %%
# twirled_circs[-1][-1].draw("mpl", idle_wires=False)

# %% [markdown]
# Look good! Now before proceeding to dynamical decoupling, we must convert to the native basis gates of the backend so that we can retrieve gate timing information, which is necessary to add dynamical decoupling passes. (Unless you set the keyword argument `transpile_added_paulis=True` in the above). You will also need to run this before running on a backend.

# %%
# from qiskit_research.utils.convenience import transpile_paulis

# twirled_circs_t = transpile_paulis(twirled_circs)

# %% [markdown]
# ## Dynamical Decoupling
#
# Video Companion: ["Nick Knows - Dynamical Decoupling"](https://www.youtube.com/watch?v=67jRWQuW3Fk&list=PLOFEBzvs-VvodTtg75jH3t2levcnVlrkk&index=10) <br>
#
# Dynamical decoupling (DD) is a way of modifying the noise power spectrum $S(\omega)$ observed by qubits (see [this recent review](https://arxiv.org/abs/2207.03670)), and is typically implemented by a sequence of gates scheduled during a given qubit idle time that compose to the identity with specific delay times to fill the idle time in a calculated manner. Considerations for which sequences to use may involve decoherent error due to idle time versus single-qubit gate errors and/or crosstalk during two-qubit gates. Because the addition of gates is not always in the set of `basis_gates` defined by the backend, `add_pulse_cals=True` uses [Pulse Gates](https://qiskit.org/documentation/tutorials/circuits_advanced/05_pulse_gates.html) to add the correct implementation to the circuit with added DD.

# %%
from qiskit_research.utils.convenience import add_dynamical_decoupling

# twirled_circs_with_dd = add_dynamical_decoupling(
circs_with_dd = add_dynamical_decoupling(
    # twirled_circs_t, backend, "XpXm", add_pulse_cals=True
    circs, backend, "X2pm", add_pulse_cals=True
)

# %%
from qiskit.visualization import timeline_drawer

# this just displays a small range
# timeline_drawer(twirled_circs_with_dd[-1][-1], time_range=[1, 20000], show_idle=False)
timeline_drawer(circs_with_dd[0], time_range=[0, 1000], show_idle=False)

# %%
from qiskit import schedule
from qiskit.pulse import ControlChannel, DriveChannel
circ_sched = schedule(circs_with_dd[0], backend)

# %%
circ_sched.draw(time_range=[0, 1000])

# %%
from qiskit.pulse import Play
for (time, inst) in circ_sched.instructions:
    if isinstance(inst, Play):
        print(time, inst)
# Out:
# 0 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 160 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 160 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 320 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 320 Play(GaussianSquare(duration=256, amp=(-0.012175940064760393-0.0018978820858134293j), sigma=64, width=0), DriveChannel(11))
# 320 Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# 480 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 576 Play(GaussianSquare(duration=256, amp=(0.012175940064760393+0.0018978820858134276j), sigma=64, width=0), DriveChannel(11))
# 576 Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# 672 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 832 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 832 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 992 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 992 Play(Drag(duration=160, amp=(-3.494450186656293e-17-0.19022900802034054j), sigma=40, beta=-0.03919302406331189, name='Ym_d14'), DriveChannel(14), name='Ym_d14')
# 1152 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 1152 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 1744 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 1904 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 1904 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 2496 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 2656 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 2656 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 2816 Play(Drag(duration=160, amp=(-0.0023256199072893943+0.09875807751674502j), sigma=40, beta=-1.3062205340440922, name='Y90p_d11'), DriveChannel(11), name='Y90p_d11')
# 2816 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 2976 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 2976 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 3424 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 3568 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 3728 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 3728 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 4320 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 4320 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 4480 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 4640 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 4800 Play(Drag(duration=160, amp=(-0.0023256199072893943+0.09875807751674502j), sigma=40, beta=-1.3062205340440922, name='Y90p_d11'), DriveChannel(11), name='Y90p_d11')
# 4800 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 4960 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 4960 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 5552 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 5712 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 5712 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 6304 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 6304 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 6304 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 6464 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 6464 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 6624 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 6624 Play(Drag(duration=160, amp=(-0.0004506870863602307+0.1026455029423071j), sigma=40, beta=-0.3907942002145771, name='Y90p_d16'), DriveChannel(16), name='Y90p_d16')
# 6784 Play(GaussianSquare(duration=640, amp=(0.044909543594368224+0.0005134852822265809j), sigma=64, width=384, name='CR90p_d16_u31'), DriveChannel(16), name='CR90p_d16_u31')
# 6784 Play(GaussianSquare(duration=640, amp=(-0.31192099951339886+0.09819416332109884j), sigma=64, width=384, name='CR90p_u31'), ControlChannel(31), name='CR90p_u31')
# 7424 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 7584 Play(GaussianSquare(duration=640, amp=(-0.044909543594368224-0.0005134852822265754j), sigma=64, width=384, name='CR90m_d16_u31'), DriveChannel(16), name='CR90m_d16_u31')
# 7584 Play(GaussianSquare(duration=640, amp=(0.31192099951339886-0.09819416332109888j), sigma=64, width=384, name='CR90m_u31'), ControlChannel(31), name='CR90m_u31')
# 7648 Play(Drag(duration=160, amp=(0.1967898497266237+0j), sigma=40, beta=-1.2783891769571305, name='Xp_d11'), DriveChannel(11), name='Xp_d11')
# 8224 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 8224 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 8384 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 8544 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 8544 Play(Drag(duration=160, amp=(-0.0004506870863602307+0.1026455029423071j), sigma=40, beta=-0.3907942002145771, name='Y90p_d16'), DriveChannel(16), name='Y90p_d16')
# 8704 Play(GaussianSquare(duration=640, amp=(0.044909543594368224+0.0005134852822265809j), sigma=64, width=384, name='CR90p_d16_u31'), DriveChannel(16), name='CR90p_d16_u31')
# 8704 Play(GaussianSquare(duration=640, amp=(-0.31192099951339886+0.09819416332109884j), sigma=64, width=384, name='CR90p_u31'), ControlChannel(31), name='CR90p_u31')
# 8800 Play(Drag(duration=160, amp=(-0.1867474210992195-0j), sigma=40, beta=-1.1600636893755543), DriveChannel(8))
# 9344 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 9504 Play(GaussianSquare(duration=640, amp=(-0.044909543594368224-0.0005134852822265754j), sigma=64, width=384, name='CR90m_d16_u31'), DriveChannel(16), name='CR90m_d16_u31')
# 9504 Play(GaussianSquare(duration=640, amp=(0.31192099951339886-0.09819416332109888j), sigma=64, width=384, name='CR90m_u31'), ControlChannel(31), name='CR90m_u31')
# 10144 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 10144 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 10208 Play(Drag(duration=160, amp=(-0.1967898497266237-0j), sigma=40, beta=-1.2783891769571305), DriveChannel(11))
# 10304 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 10464 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 10624 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 10624 Play(Drag(duration=160, amp=(-0.0004506870863602307+0.1026455029423071j), sigma=40, beta=-0.3907942002145771, name='Y90p_d16'), DriveChannel(16), name='Y90p_d16')
# 10784 Play(GaussianSquare(duration=640, amp=(0.044909543594368224+0.0005134852822265809j), sigma=64, width=384, name='CR90p_d16_u31'), DriveChannel(16), name='CR90p_d16_u31')
# 10784 Play(GaussianSquare(duration=640, amp=(-0.31192099951339886+0.09819416332109884j), sigma=64, width=384, name='CR90p_u31'), ControlChannel(31), name='CR90p_u31')
# 11424 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 11552 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 11552 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 11584 Play(GaussianSquare(duration=640, amp=(-0.044909543594368224-0.0005134852822265754j), sigma=64, width=384, name='CR90m_d16_u31'), DriveChannel(16), name='CR90m_d16_u31')
# 11584 Play(GaussianSquare(duration=640, amp=(0.31192099951339886-0.09819416332109888j), sigma=64, width=384, name='CR90m_u31'), ControlChannel(31), name='CR90m_u31')
# 11712 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 11712 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 11872 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 11872 Play(GaussianSquare(duration=256, amp=(-0.012175940064760393-0.0018978820858134293j), sigma=64, width=0), DriveChannel(11))
# 11872 Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# 12032 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 12128 Play(GaussianSquare(duration=256, amp=(0.012175940064760393+0.0018978820858134276j), sigma=64, width=0), DriveChannel(11))
# 12128 Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# 12224 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 12224 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 12384 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 12384 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 12384 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 12544 Play(Drag(duration=160, amp=(-0.0023256199072893943+0.09875807751674502j), sigma=40, beta=-1.3062205340440922, name='Y90p_d11'), DriveChannel(11), name='Y90p_d11')
# 12544 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 12704 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 12704 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 13248 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 13296 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 13456 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 13456 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 14048 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 14048 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 14208 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 14208 Play(Drag(duration=160, amp=(-3.494450186656293e-17-0.19022900802034054j), sigma=40, beta=-0.03919302406331189, name='Ym_d14'), DriveChannel(14), name='Ym_d14')
# 14368 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 14368 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 14848 Play(Drag(duration=160, amp=(-0.1867474210992195-0j), sigma=40, beta=-1.1600636893755543), DriveChannel(8))
# 14960 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 15120 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 15120 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 15296 Play(Drag(duration=160, amp=(0.20553597356225373+0j), sigma=40, beta=-0.4107474032898753, name='Xp_d16'), DriveChannel(16), name='Xp_d16')
# 15712 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 15712 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 15840 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 15872 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 15872 Play(GaussianSquare(duration=256, amp=(-0.012175940064760393-0.0018978820858134293j), sigma=64, width=0), DriveChannel(11))
# 15872 Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# 16032 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 16128 Play(GaussianSquare(duration=256, amp=(0.012175940064760393+0.0018978820858134276j), sigma=64, width=0), DriveChannel(11))
# 16128 Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# 16256 Play(Drag(duration=160, amp=(-0.19022900802034054-0j), sigma=40, beta=-0.03919302406331189), DriveChannel(14))
# 16384 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 16384 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 16544 Play(Drag(duration=160, amp=(-0.0023256199072893943+0.09875807751674502j), sigma=40, beta=-1.3062205340440922, name='Y90p_d11'), DriveChannel(11), name='Y90p_d11')
# 16544 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 16704 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 16704 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 16880 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 17296 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 17456 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 17456 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 17712 Play(Drag(duration=160, amp=(-0.1867474210992195-0j), sigma=40, beta=-1.1600636893755543), DriveChannel(8))
# 18048 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 18048 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 18208 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 18208 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 18256 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 18368 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 18368 Play(GaussianSquare(duration=256, amp=(-0.012175940064760393-0.0018978820858134293j), sigma=64, width=0), DriveChannel(11))
# 18368 Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# 18512 Play(Drag(duration=160, amp=(-0.19022900802034054-0j), sigma=40, beta=-0.03919302406331189), DriveChannel(14))
# 18528 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 18624 Play(GaussianSquare(duration=256, amp=(0.012175940064760393+0.0018978820858134276j), sigma=64, width=0), DriveChannel(11))
# 18624 Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# 18720 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 18880 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 18880 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 19040 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 19040 Play(Drag(duration=160, amp=(-3.494450186656293e-17-0.19022900802034054j), sigma=40, beta=-0.03919302406331189, name='Ym_d14'), DriveChannel(14), name='Ym_d14')
# 19200 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 19200 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 19792 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 19952 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 19952 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 20544 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 20704 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 20704 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 20864 Play(Drag(duration=160, amp=(-0.0023256199072893943+0.09875807751674502j), sigma=40, beta=-1.3062205340440922, name='Y90p_d11'), DriveChannel(11), name='Y90p_d11')
# 20864 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 21024 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 21024 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 21280 Play(Drag(duration=160, amp=(-0.20553597356225373-0j), sigma=40, beta=-0.4107474032898753), DriveChannel(16))
# 21472 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 21616 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 21776 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 21776 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 22368 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 22368 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 22528 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 22688 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 22848 Play(Drag(duration=160, amp=(-0.0023256199072893943+0.09875807751674502j), sigma=40, beta=-1.3062205340440922, name='Y90p_d11'), DriveChannel(11), name='Y90p_d11')
# 22848 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 23008 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 23008 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 23600 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 23760 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 23760 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 24352 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 24352 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 24352 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 24512 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 24512 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 24672 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 24672 Play(Drag(duration=160, amp=(-0.0004506870863602307+0.1026455029423071j), sigma=40, beta=-0.3907942002145771, name='Y90p_d16'), DriveChannel(16), name='Y90p_d16')
# 24832 Play(GaussianSquare(duration=640, amp=(0.044909543594368224+0.0005134852822265809j), sigma=64, width=384, name='CR90p_d16_u31'), DriveChannel(16), name='CR90p_d16_u31')
# 24832 Play(GaussianSquare(duration=640, amp=(-0.31192099951339886+0.09819416332109884j), sigma=64, width=384, name='CR90p_u31'), ControlChannel(31), name='CR90p_u31')
# 25472 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 25632 Play(GaussianSquare(duration=640, amp=(-0.044909543594368224-0.0005134852822265754j), sigma=64, width=384, name='CR90m_d16_u31'), DriveChannel(16), name='CR90m_d16_u31')
# 25632 Play(GaussianSquare(duration=640, amp=(0.31192099951339886-0.09819416332109888j), sigma=64, width=384, name='CR90m_u31'), ControlChannel(31), name='CR90m_u31')
# 25696 Play(Drag(duration=160, amp=(0.1967898497266237+0j), sigma=40, beta=-1.2783891769571305, name='Xp_d11'), DriveChannel(11), name='Xp_d11')
# 26272 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 26272 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 26432 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 26592 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 26592 Play(Drag(duration=160, amp=(-0.0004506870863602307+0.1026455029423071j), sigma=40, beta=-0.3907942002145771, name='Y90p_d16'), DriveChannel(16), name='Y90p_d16')
# 26752 Play(GaussianSquare(duration=640, amp=(0.044909543594368224+0.0005134852822265809j), sigma=64, width=384, name='CR90p_d16_u31'), DriveChannel(16), name='CR90p_d16_u31')
# 26752 Play(GaussianSquare(duration=640, amp=(-0.31192099951339886+0.09819416332109884j), sigma=64, width=384, name='CR90p_u31'), ControlChannel(31), name='CR90p_u31')
# 26848 Play(Drag(duration=160, amp=(-0.1867474210992195-0j), sigma=40, beta=-1.1600636893755543), DriveChannel(8))
# 27392 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 27552 Play(GaussianSquare(duration=640, amp=(-0.044909543594368224-0.0005134852822265754j), sigma=64, width=384, name='CR90m_d16_u31'), DriveChannel(16), name='CR90m_d16_u31')
# 27552 Play(GaussianSquare(duration=640, amp=(0.31192099951339886-0.09819416332109888j), sigma=64, width=384, name='CR90m_u31'), ControlChannel(31), name='CR90m_u31')
# 28192 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 28192 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 28256 Play(Drag(duration=160, amp=(-0.1967898497266237-0j), sigma=40, beta=-1.2783891769571305), DriveChannel(11))
# 28352 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 28512 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 28672 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 28672 Play(Drag(duration=160, amp=(-0.0004506870863602307+0.1026455029423071j), sigma=40, beta=-0.3907942002145771, name='Y90p_d16'), DriveChannel(16), name='Y90p_d16')
# 28832 Play(GaussianSquare(duration=640, amp=(0.044909543594368224+0.0005134852822265809j), sigma=64, width=384, name='CR90p_d16_u31'), DriveChannel(16), name='CR90p_d16_u31')
# 28832 Play(GaussianSquare(duration=640, amp=(-0.31192099951339886+0.09819416332109884j), sigma=64, width=384, name='CR90p_u31'), ControlChannel(31), name='CR90p_u31')
# 29472 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 29600 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 29600 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 29632 Play(GaussianSquare(duration=640, amp=(-0.044909543594368224-0.0005134852822265754j), sigma=64, width=384, name='CR90m_d16_u31'), DriveChannel(16), name='CR90m_d16_u31')
# 29632 Play(GaussianSquare(duration=640, amp=(0.31192099951339886-0.09819416332109888j), sigma=64, width=384, name='CR90m_u31'), ControlChannel(31), name='CR90m_u31')
# 29760 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 29760 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 29920 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 29920 Play(GaussianSquare(duration=256, amp=(-0.012175940064760393-0.0018978820858134293j), sigma=64, width=0), DriveChannel(11))
# 29920 Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# 30080 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 30176 Play(GaussianSquare(duration=256, amp=(0.012175940064760393+0.0018978820858134276j), sigma=64, width=0), DriveChannel(11))
# 30176 Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# 30272 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 30272 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 30432 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 30432 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 30432 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 30592 Play(Drag(duration=160, amp=(-0.0023256199072893943+0.09875807751674502j), sigma=40, beta=-1.3062205340440922, name='Y90p_d11'), DriveChannel(11), name='Y90p_d11')
# 30592 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 30752 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 30752 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 31296 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 31344 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 31504 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 31504 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 32096 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 32096 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 32256 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 32256 Play(Drag(duration=160, amp=(-3.494450186656293e-17-0.19022900802034054j), sigma=40, beta=-0.03919302406331189, name='Ym_d14'), DriveChannel(14), name='Ym_d14')
# 32416 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 32416 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 32896 Play(Drag(duration=160, amp=(-0.1867474210992195-0j), sigma=40, beta=-1.1600636893755543), DriveChannel(8))
# 33008 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 33168 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 33168 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 33344 Play(Drag(duration=160, amp=(0.20553597356225373+0j), sigma=40, beta=-0.4107474032898753, name='Xp_d16'), DriveChannel(16), name='Xp_d16')
# 33760 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 33760 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 33888 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 33920 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 33920 Play(GaussianSquare(duration=256, amp=(-0.012175940064760393-0.0018978820858134293j), sigma=64, width=0), DriveChannel(11))
# 33920 Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# 34080 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 34176 Play(GaussianSquare(duration=256, amp=(0.012175940064760393+0.0018978820858134276j), sigma=64, width=0), DriveChannel(11))
# 34176 Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# 34304 Play(Drag(duration=160, amp=(-0.19022900802034054-0j), sigma=40, beta=-0.03919302406331189), DriveChannel(14))
# 34432 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 34432 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 34592 Play(Drag(duration=160, amp=(-0.0023256199072893943+0.09875807751674502j), sigma=40, beta=-1.3062205340440922, name='Y90p_d11'), DriveChannel(11), name='Y90p_d11')
# 34592 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 34752 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 34752 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 34928 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 35344 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 35504 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 35504 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 35760 Play(Drag(duration=160, amp=(-0.1867474210992195-0j), sigma=40, beta=-1.1600636893755543), DriveChannel(8))
# 36096 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 36096 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 36256 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 36256 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 36304 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 36416 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 36416 Play(GaussianSquare(duration=256, amp=(-0.012175940064760393-0.0018978820858134293j), sigma=64, width=0), DriveChannel(11))
# 36416 Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# 36560 Play(Drag(duration=160, amp=(-0.19022900802034054-0j), sigma=40, beta=-0.03919302406331189), DriveChannel(14))
# 36576 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 36672 Play(GaussianSquare(duration=256, amp=(0.012175940064760393+0.0018978820858134276j), sigma=64, width=0), DriveChannel(11))
# 36672 Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# 36768 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 36928 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 36928 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 37088 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 37088 Play(Drag(duration=160, amp=(-3.494450186656293e-17-0.19022900802034054j), sigma=40, beta=-0.03919302406331189, name='Ym_d14'), DriveChannel(14), name='Ym_d14')
# 37248 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 37248 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 37840 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 38000 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 38000 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 38592 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 38752 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 38752 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 38912 Play(Drag(duration=160, amp=(-0.0023256199072893943+0.09875807751674502j), sigma=40, beta=-1.3062205340440922, name='Y90p_d11'), DriveChannel(11), name='Y90p_d11')
# 38912 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 39072 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 39072 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 39328 Play(Drag(duration=160, amp=(-0.20553597356225373-0j), sigma=40, beta=-0.4107474032898753), DriveChannel(16))
# 39520 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 39664 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 39824 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 39824 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# ...
# 78496 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 78496 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 78656 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 78656 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 78816 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 78816 Play(Drag(duration=160, amp=(-0.0004506870863602307+0.1026455029423071j), sigma=40, beta=-0.3907942002145771, name='Y90p_d16'), DriveChannel(16), name='Y90p_d16')
# 78976 Play(GaussianSquare(duration=640, amp=(0.044909543594368224+0.0005134852822265809j), sigma=64, width=384, name='CR90p_d16_u31'), DriveChannel(16), name='CR90p_d16_u31')
# 78976 Play(GaussianSquare(duration=640, amp=(-0.31192099951339886+0.09819416332109884j), sigma=64, width=384, name='CR90p_u31'), ControlChannel(31), name='CR90p_u31')
# 79616 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 79776 Play(GaussianSquare(duration=640, amp=(-0.044909543594368224-0.0005134852822265754j), sigma=64, width=384, name='CR90m_d16_u31'), DriveChannel(16), name='CR90m_d16_u31')
# 79776 Play(GaussianSquare(duration=640, amp=(0.31192099951339886-0.09819416332109888j), sigma=64, width=384, name='CR90m_u31'), ControlChannel(31), name='CR90m_u31')
# 79840 Play(Drag(duration=160, amp=(0.1967898497266237+0j), sigma=40, beta=-1.2783891769571305, name='Xp_d11'), DriveChannel(11), name='Xp_d11')
# 80416 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 80416 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 80576 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 80736 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 80736 Play(Drag(duration=160, amp=(-0.0004506870863602307+0.1026455029423071j), sigma=40, beta=-0.3907942002145771, name='Y90p_d16'), DriveChannel(16), name='Y90p_d16')
# 80896 Play(GaussianSquare(duration=640, amp=(0.044909543594368224+0.0005134852822265809j), sigma=64, width=384, name='CR90p_d16_u31'), DriveChannel(16), name='CR90p_d16_u31')
# 80896 Play(GaussianSquare(duration=640, amp=(-0.31192099951339886+0.09819416332109884j), sigma=64, width=384, name='CR90p_u31'), ControlChannel(31), name='CR90p_u31')
# 80992 Play(Drag(duration=160, amp=(-0.1867474210992195-0j), sigma=40, beta=-1.1600636893755543), DriveChannel(8))
# 81536 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 81696 Play(GaussianSquare(duration=640, amp=(-0.044909543594368224-0.0005134852822265754j), sigma=64, width=384, name='CR90m_d16_u31'), DriveChannel(16), name='CR90m_d16_u31')
# 81696 Play(GaussianSquare(duration=640, amp=(0.31192099951339886-0.09819416332109888j), sigma=64, width=384, name='CR90m_u31'), ControlChannel(31), name='CR90m_u31')
# 82336 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 82336 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 82400 Play(Drag(duration=160, amp=(-0.1967898497266237-0j), sigma=40, beta=-1.2783891769571305), DriveChannel(11))
# 82496 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 82656 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 82816 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 82816 Play(Drag(duration=160, amp=(-0.0004506870863602307+0.1026455029423071j), sigma=40, beta=-0.3907942002145771, name='Y90p_d16'), DriveChannel(16), name='Y90p_d16')
# 82976 Play(GaussianSquare(duration=640, amp=(0.044909543594368224+0.0005134852822265809j), sigma=64, width=384, name='CR90p_d16_u31'), DriveChannel(16), name='CR90p_d16_u31')
# 82976 Play(GaussianSquare(duration=640, amp=(-0.31192099951339886+0.09819416332109884j), sigma=64, width=384, name='CR90p_u31'), ControlChannel(31), name='CR90p_u31')
# 83616 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 83744 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 83744 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 83776 Play(GaussianSquare(duration=640, amp=(-0.044909543594368224-0.0005134852822265754j), sigma=64, width=384, name='CR90m_d16_u31'), DriveChannel(16), name='CR90m_d16_u31')
# 83776 Play(GaussianSquare(duration=640, amp=(0.31192099951339886-0.09819416332109888j), sigma=64, width=384, name='CR90m_u31'), ControlChannel(31), name='CR90m_u31')
# 83904 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 83904 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 84064 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 84064 Play(GaussianSquare(duration=256, amp=(-0.012175940064760393-0.0018978820858134293j), sigma=64, width=0), DriveChannel(11))
# 84064 Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# 84224 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 84320 Play(GaussianSquare(duration=256, amp=(0.012175940064760393+0.0018978820858134276j), sigma=64, width=0), DriveChannel(11))
# 84320 Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# 84416 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 84416 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 84576 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 84576 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 84576 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 84736 Play(Drag(duration=160, amp=(-0.0023256199072893943+0.09875807751674502j), sigma=40, beta=-1.3062205340440922, name='Y90p_d11'), DriveChannel(11), name='Y90p_d11')
# 84736 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 84896 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 84896 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 85440 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 85488 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 85648 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 85648 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 85952 Play(Drag(duration=160, amp=(0.20553597356225373+0j), sigma=40, beta=-0.4107474032898753, name='Xp_d16'), DriveChannel(16), name='Xp_d16')
# 86240 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 86240 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 86400 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 86400 Play(Drag(duration=160, amp=(-3.494450186656293e-17-0.19022900802034054j), sigma=40, beta=-0.03919302406331189, name='Ym_d14'), DriveChannel(14), name='Ym_d14')
# 86560 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 86560 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 87040 Play(Drag(duration=160, amp=(-0.1867474210992195-0j), sigma=40, beta=-1.1600636893755543), DriveChannel(8))
# 87152 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 87312 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 87312 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 87904 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 87904 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 88032 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 88064 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 88064 Play(GaussianSquare(duration=256, amp=(-0.012175940064760393-0.0018978820858134293j), sigma=64, width=0), DriveChannel(11))
# 88064 Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# 88224 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 88320 Play(GaussianSquare(duration=256, amp=(0.012175940064760393+0.0018978820858134276j), sigma=64, width=0), DriveChannel(11))
# 88320 Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# 88448 Play(Drag(duration=160, amp=(-0.19022900802034054-0j), sigma=40, beta=-0.03919302406331189), DriveChannel(14))
# 88576 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 88576 Play(Drag(duration=160, amp=(0.09369585550497005+0.0011357143456304192j), sigma=40, beta=-1.1371020777857848, name='X90p_d8'), DriveChannel(8), name='X90p_d8')
# 88736 Play(Drag(duration=160, amp=(-0.0023256199072893943+0.09875807751674502j), sigma=40, beta=-1.3062205340440922, name='Y90p_d11'), DriveChannel(11), name='Y90p_d11')
# 88736 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 88864 Play(Drag(duration=160, amp=(-0.20553597356225373-0j), sigma=40, beta=-0.4107474032898753), DriveChannel(16))
# 88896 Play(GaussianSquare(duration=592, amp=(0.05285765053282398+0.003313403186388433j), sigma=64, width=336, name='CR90p_d11_u29'), DriveChannel(11), name='CR90p_d11_u29')
# 88896 Play(GaussianSquare(duration=592, amp=(0.2627984155771997-0.22750304366857269j), sigma=64, width=336, name='CR90p_u29'), ControlChannel(29), name='CR90p_u29')
# 89104 Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# 89488 Play(Drag(duration=160, amp=(0.19022900802034054+0j), sigma=40, beta=-0.03919302406331189, name='Xp_d14'), DriveChannel(14), name='Xp_d14')
# 89648 Play(GaussianSquare(duration=592, amp=(-0.05285765053282398-0.0033134031863884263j), sigma=64, width=336, name='CR90m_d11_u29'), DriveChannel(11), name='CR90m_d11_u29')
# 89648 Play(GaussianSquare(duration=592, amp=(-0.26279841557719963+0.2275030436685727j), sigma=64, width=336, name='CR90m_u29'), ControlChannel(29), name='CR90m_u29')
# 90032 Play(Drag(duration=160, amp=(-0.1867474210992195-0j), sigma=40, beta=-1.1600636893755543), DriveChannel(8))
# 90240 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 90240 Play(Drag(duration=160, amp=(0.0004112511883289007-0.09517983645735426j), sigma=40, beta=-0.07061384616485276, name='Y90m_d14'), DriveChannel(14), name='Y90m_d14')
# 90400 Play(Drag(duration=160, amp=(0.09875807751674502+0.0023256199072894074j), sigma=40, beta=-1.3062205340440922, name='X90p_d11'), DriveChannel(11), name='X90p_d11')
# 90400 Play(Drag(duration=160, amp=(0.09517983645735426+0.0004112511883289094j), sigma=40, beta=-0.07061384616485276, name='X90p_d14'), DriveChannel(14), name='X90p_d14')
# 90400 Play(Drag(duration=160, amp=(0.1026455029423071+0.0004506870863602267j), sigma=40, beta=-0.3907942002145771, name='X90p_d16'), DriveChannel(16), name='X90p_d16')
# 90560 Play(GaussianSquare(duration=1792, amp=(0.20733946426982258-0.30644795081106835j), sigma=64, width=1536, name='M_m11'), MeasureChannel(11), name='M_m11')
# 90560 Play(GaussianSquare(duration=1792, amp=(0.1322169486301392-0.1763372861732173j), sigma=64, width=1536, name='M_m14'), MeasureChannel(14), name='M_m14')
# 90560 Play(GaussianSquare(duration=1792, amp=(0.27651922102689724+0.08739061964923889j), sigma=64, width=1536, name='M_m16'), MeasureChannel(16), name='M_m16')
# 90560 Play(GaussianSquare(duration=1792, amp=(0.1981646616344629+0.3335787266587887j), sigma=64, width=1536, name='M_m8'), MeasureChannel(8), name='M_m8')

# %%
conf = backend.configuration()
defs = backend.defaults()
props = backend.properties()

# %%
conf.control_channels
# Out:
# {(0, 1): [ControlChannel(0)],
#  (1, 0): [ControlChannel(1)],
#  (5, 3): [ControlChannel(10)],
#  (5, 8): [ControlChannel(11)],
#  (6, 7): [ControlChannel(12)],
#  (7, 4): [ControlChannel(13)],
#  (7, 6): [ControlChannel(14)],
#  (7, 10): [ControlChannel(15)],
#  (8, 5): [ControlChannel(16)],
#  (8, 9): [ControlChannel(17)],
#  (8, 11): [ControlChannel(18)],
#  (9, 8): [ControlChannel(19)],
#  (1, 2): [ControlChannel(2)],
#  (10, 7): [ControlChannel(20)],
#  (10, 12): [ControlChannel(21)],
#  (11, 8): [ControlChannel(22)],
#  (11, 14): [ControlChannel(23)],
#  (12, 10): [ControlChannel(24)],
#  (12, 13): [ControlChannel(25)],
#  (12, 15): [ControlChannel(26)],
#  (13, 12): [ControlChannel(27)],
#  (13, 14): [ControlChannel(28)],
#  (14, 11): [ControlChannel(29)],
#  (1, 4): [ControlChannel(3)],
#  (14, 13): [ControlChannel(30)],
#  (14, 16): [ControlChannel(31)],
#  (15, 12): [ControlChannel(32)],
#  (15, 18): [ControlChannel(33)],
#  (16, 14): [ControlChannel(34)],
#  (16, 19): [ControlChannel(35)],
#  (17, 18): [ControlChannel(36)],
#  (18, 15): [ControlChannel(37)],
#  (18, 17): [ControlChannel(38)],
#  (18, 21): [ControlChannel(39)],
#  (2, 1): [ControlChannel(4)],
#  (19, 16): [ControlChannel(40)],
#  (19, 20): [ControlChannel(41)],
#  (19, 22): [ControlChannel(42)],
#  (20, 19): [ControlChannel(43)],
#  (21, 18): [ControlChannel(44)],
#  (21, 23): [ControlChannel(45)],
#  (22, 19): [ControlChannel(46)],
#  (22, 25): [ControlChannel(47)],
#  (23, 21): [ControlChannel(48)],
#  (23, 24): [ControlChannel(49)],
#  (2, 3): [ControlChannel(5)],
#  (24, 23): [ControlChannel(50)],
#  (24, 25): [ControlChannel(51)],
#  (25, 22): [ControlChannel(52)],
#  (25, 24): [ControlChannel(53)],
#  (25, 26): [ControlChannel(54)],
#  (26, 25): [ControlChannel(55)],
#  (3, 2): [ControlChannel(6)],
#  (3, 5): [ControlChannel(7)],
#  (4, 1): [ControlChannel(8)],
#  (4, 7): [ControlChannel(9)]}

# %%
d_chan = 8 # 14
u_chan = 18 # 29

for cidx, circ in enumerate(circs_with_dd):
     circ_sched = schedule(circ, backend)
     prev_end = 0
     # for (time, inst) in circ_sched.filter(channels=[DriveChannel(14), ControlChannel(29)]).instructions:
     for (time, inst) in circ_sched.filter(channels=[DriveChannel(d_chan), ControlChannel(u_chan)]).instructions:
          # print('Circuit: {}, Time: {}, Drive: {}, Ctrl: {}'.format(cidx, time, inst.ch_duration(DriveChannel(14)), inst.ch_duration(ControlChannel(29))))
          cur_time = time + inst.ch_duration(DriveChannel(d_chan)) + inst.ch_duration(ControlChannel(u_chan))
          if (inst.ch_duration(DriveChannel(d_chan)) + inst.ch_duration(ControlChannel(u_chan))) > 0:
               # print('{} - {}'.format(prev_end, time))
               if (time < prev_end):
                    print('Problem at time {} after time {} with circuit {} for Inst {}'.format(cur_time, prev_end, cidx, inst))
          
               prev_end = cur_time
          # if (time+inst.ch_duration(DriveChannel(14)) < prev_end):
          #      print('Problem at time {} with circuit {}'.format(prev_end, cidx))
          # prev_end = time + inst.ch_duration(DriveChannel(14))
# Out:
# Problem at time 576 after time 480 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 640 after time 576 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 832 after time 640 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 12128 after time 12032 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 12192 after time 12128 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 12384 after time 12192 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 16128 after time 16032 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 16192 after time 16128 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 16384 after time 16192 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 18624 after time 18528 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 18688 after time 18624 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 18880 after time 18688 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 30176 after time 30080 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 30240 after time 30176 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 30432 after time 30240 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 34176 after time 34080 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 34240 after time 34176 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 34432 after time 34240 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 36672 after time 36576 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 36736 after time 36672 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 36928 after time 36736 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 48224 after time 48128 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 48288 after time 48224 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 48480 after time 48288 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 52224 after time 52128 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 52288 after time 52224 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 52480 after time 52288 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 54720 after time 54624 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 54784 after time 54720 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 54976 after time 54784 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 66272 after time 66176 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 66336 after time 66272 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 66528 after time 66336 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 70272 after time 70176 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 70336 after time 70272 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 70528 after time 70336 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 72768 after time 72672 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 72832 after time 72768 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 73024 after time 72832 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 84320 after time 84224 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 84384 after time 84320 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 84576 after time 84384 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 88320 after time 88224 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 88384 after time 88320 with circuit 0 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 88576 after time 88384 with circuit 0 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 576 after time 480 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 640 after time 576 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 832 after time 640 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 12128 after time 12032 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 12192 after time 12128 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 12384 after time 12192 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 16128 after time 16032 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 16192 after time 16128 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 16384 after time 16192 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 18624 after time 18528 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 18688 after time 18624 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 18880 after time 18688 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 30176 after time 30080 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 30240 after time 30176 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 30432 after time 30240 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 34176 after time 34080 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 34240 after time 34176 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 34432 after time 34240 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 36672 after time 36576 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 36736 after time 36672 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 36928 after time 36736 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 48224 after time 48128 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 48288 after time 48224 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 48480 after time 48288 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 52224 after time 52128 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 52288 after time 52224 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 52480 after time 52288 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 54720 after time 54624 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 54784 after time 54720 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 54976 after time 54784 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 66272 after time 66176 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 66336 after time 66272 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 66528 after time 66336 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 70272 after time 70176 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 70336 after time 70272 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 70528 after time 70336 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 72768 after time 72672 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 72832 after time 72768 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 73024 after time 72832 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 84320 after time 84224 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 84384 after time 84320 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 84576 after time 84384 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 88320 after time 88224 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 88384 after time 88320 with circuit 1 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 88576 after time 88384 with circuit 1 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 576 after time 480 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 640 after time 576 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 832 after time 640 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 12128 after time 12032 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 12192 after time 12128 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 12384 after time 12192 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 16128 after time 16032 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 16192 after time 16128 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 16384 after time 16192 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 18624 after time 18528 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 18688 after time 18624 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 18880 after time 18688 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 30176 after time 30080 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 30240 after time 30176 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 30432 after time 30240 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 34176 after time 34080 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 34240 after time 34176 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 34432 after time 34240 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 36672 after time 36576 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 36736 after time 36672 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 36928 after time 36736 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 48224 after time 48128 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 48288 after time 48224 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 48480 after time 48288 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 52224 after time 52128 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 52288 after time 52224 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 52480 after time 52288 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 54720 after time 54624 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 54784 after time 54720 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 54976 after time 54784 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 66272 after time 66176 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 66336 after time 66272 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 66528 after time 66336 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 70272 after time 70176 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 70336 after time 70272 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 70528 after time 70336 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 72768 after time 72672 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 72832 after time 72768 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 73024 after time 72832 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 84320 after time 84224 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 84384 after time 84320 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 84576 after time 84384 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 88320 after time 88224 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(-0.08570863650429084-0.006490148262258625j), sigma=64, width=0), ControlChannel(18))
# Problem at time 88384 after time 88320 with circuit 2 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 88576 after time 88384 with circuit 2 for Inst Play(GaussianSquare(duration=256, amp=(0.08570863650429084+0.0064901482622586135j), sigma=64, width=0), ControlChannel(18))
# Problem at time 576 after time 480 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 640 after time 576 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 832 after time 640 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 12128 after time 12032 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 12192 after time 12128 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 12384 after time 12192 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 16128 after time 16032 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 16192 after time 16128 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 16384 after time 16192 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 18624 after time 18528 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 18688 after time 18624 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 18880 after time 18688 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 30176 after time 30080 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 30240 after time 30176 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 30432 after time 30240 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 34176 after time 34080 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 34240 after time 34176 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 34432 after time 34240 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 36672 after time 36576 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 36736 after time 36672 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 36928 after time 36736 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 48224 after time 48128 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 48288 after time 48224 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 48480 after time 48288 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 52224 after time 52128 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 52288 after time 52224 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 52480 after time 52288 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 54720 after time 54624 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 54784 after time 54720 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 54976 after time 54784 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 66272 after time 66176 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 66336 after time 66272 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 66528 after time 66336 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 70272 after time 70176 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 70336 after time 70272 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 70528 after time 70336 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 72768 after time 72672 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 72832 after time 72768 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 73024 after time 72832 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 84320 after time 84224 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 84384 after time 84320 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 84576 after time 84384 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 88320 after time 88224 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 88384 after time 88320 with circuit 3 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 88576 after time 88384 with circuit 3 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 576 after time 480 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 640 after time 576 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 832 after time 640 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 12128 after time 12032 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 12192 after time 12128 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 12384 after time 12192 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 16128 after time 16032 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 16192 after time 16128 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 16384 after time 16192 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 18624 after time 18528 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 18688 after time 18624 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 18880 after time 18688 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 30176 after time 30080 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 30240 after time 30176 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 30432 after time 30240 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 34176 after time 34080 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 34240 after time 34176 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 34432 after time 34240 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 36672 after time 36576 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 36736 after time 36672 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 36928 after time 36736 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 48224 after time 48128 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 48288 after time 48224 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 48480 after time 48288 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 52224 after time 52128 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 52288 after time 52224 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 52480 after time 52288 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 54720 after time 54624 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 54784 after time 54720 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 54976 after time 54784 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 66272 after time 66176 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 66336 after time 66272 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 66528 after time 66336 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 70272 after time 70176 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 70336 after time 70272 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 70528 after time 70336 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 72768 after time 72672 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 72832 after time 72768 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 73024 after time 72832 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 84320 after time 84224 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 84384 after time 84320 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 84576 after time 84384 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 88320 after time 88224 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 88384 after time 88320 with circuit 4 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 88576 after time 88384 with circuit 4 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 576 after time 480 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 640 after time 576 with circuit 5 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 832 after time 640 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 12128 after time 12032 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 12192 after time 12128 with circuit 5 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 12384 after time 12192 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 16128 after time 16032 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 16192 after time 16128 with circuit 5 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 16384 after time 16192 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 18624 after time 18528 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 18688 after time 18624 with circuit 5 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 18880 after time 18688 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 30176 after time 30080 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 30240 after time 30176 with circuit 5 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 30432 after time 30240 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 34176 after time 34080 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 34240 after time 34176 with circuit 5 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 34432 after time 34240 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 36672 after time 36576 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 36736 after time 36672 with circuit 5 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 36928 after time 36736 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 48224 after time 48128 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 48288 after time 48224 with circuit 5 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 48480 after time 48288 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# Problem at time 52224 after time 52128 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(-0.17141727300858167-0.01298029652451725j), sigma=64, width=0), ControlChannel(18))
# Problem at time 52288 after time 52224 with circuit 5 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 52480 after time 52288 with circuit 5 for Inst Play(GaussianSquare(duration=256, amp=(0.17141727300858167+0.012980296524517227j), sigma=64, width=0), ControlChannel(18))
# ...
# Problem at time 40192 after time 41120 with circuit 87 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 45600 after time 44512 with circuit 87 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 44672 after time 45600 with circuit 87 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 57152 after time 56064 with circuit 87 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 56224 after time 57152 with circuit 87 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 63136 after time 62048 with circuit 87 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 62208 after time 63136 with circuit 87 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 67616 after time 66528 with circuit 87 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 66688 after time 67616 with circuit 87 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 79168 after time 78080 with circuit 87 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 78240 after time 79168 with circuit 87 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 85152 after time 84064 with circuit 87 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 84224 after time 85152 with circuit 87 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 89632 after time 88544 with circuit 87 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 88704 after time 89632 with circuit 87 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 101184 after time 100096 with circuit 87 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 100256 after time 101184 with circuit 87 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 107168 after time 106080 with circuit 87 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 106240 after time 107168 with circuit 87 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 1568 after time 480 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 640 after time 1568 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 13120 after time 12032 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 12192 after time 13120 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 19104 after time 18016 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 18176 after time 19104 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 23584 after time 22496 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 22656 after time 23584 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 35136 after time 34048 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 34208 after time 35136 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 41120 after time 40032 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 40192 after time 41120 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 45600 after time 44512 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 44672 after time 45600 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 57152 after time 56064 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 56224 after time 57152 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 63136 after time 62048 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 62208 after time 63136 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 67616 after time 66528 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 66688 after time 67616 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 79168 after time 78080 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 78240 after time 79168 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 85152 after time 84064 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 84224 after time 85152 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 89632 after time 88544 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 88704 after time 89632 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 101184 after time 100096 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 100256 after time 101184 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 107168 after time 106080 with circuit 88 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 106240 after time 107168 with circuit 88 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 1568 after time 480 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 640 after time 1568 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 13120 after time 12032 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 12192 after time 13120 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 19104 after time 18016 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 18176 after time 19104 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 23584 after time 22496 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 22656 after time 23584 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 35136 after time 34048 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 34208 after time 35136 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 41120 after time 40032 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 40192 after time 41120 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 45600 after time 44512 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 44672 after time 45600 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 57152 after time 56064 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 56224 after time 57152 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 63136 after time 62048 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 62208 after time 63136 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 67616 after time 66528 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 66688 after time 67616 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 79168 after time 78080 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 78240 after time 79168 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 85152 after time 84064 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 84224 after time 85152 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 89632 after time 88544 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 88704 after time 89632 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 101184 after time 100096 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 100256 after time 101184 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')
# Problem at time 107168 after time 106080 with circuit 89 for Inst Play(GaussianSquare(duration=1248, amp=(-0.3578017993742103-0.02709396416923847j), sigma=64, width=992.4269029641605), ControlChannel(18))
# Problem at time 106240 after time 107168 with circuit 89 for Inst Play(Drag(duration=160, amp=(0.1867474210992195+0j), sigma=40, beta=-1.1600636893755543, name='Xp_d8'), DriveChannel(8), name='Xp_d8')

# %%
# from qiskit_research.utils.cost_funcs import cost_func_scaled_cr
# for circ in twirled_circs_with_dd[-1]:
#     print(evaluate_layouts(circ, scored_layouts[0][0], backend, cost_function=cost_func_scaled_cr))

# %% [markdown]
# ## Circuit Execution
#
# This runs the given circuits on the backend. This will be expanded to include different methods of running, i.e. Qiskit Runtime.

# %%
from qiskit.providers.ibmq.managed import IBMQJobManager

# # the backend only accepts a QuantumCircuit or List[QuantumCircuit]
# flattened_circs = [
#     # circ for circs in twirled_circs_with_dd for circ in circs
#     circ for circs in twirled_circs for circ in circs

# ] 

# Use Job Manager to break the circuits into multiple jobs.
job_manager = IBMQJobManager()
# ising_job_set = job_manager.run(circs, backend=backend, 
ising_job_set = job_manager.run(circs_with_dd, backend=backend, 
    name='Ising-t{}-Nt{}'.format(stop_time, num_trotter_steps), shots=5000)
# ising_job_set = job_manager.run(flattened_circs, backend=backend, name='Ising-t{}-Nt{}-sim'.format(stop_time, num_trotter_steps))

ising_job_set_id = ising_job_set.job_set_id()
print("Job Set ID: {}".format(ising_job_set_id))
# Out:
# Job Set ID: 7aec82091817425880af55e9d8e5f6f6-16667976273163059

# %%
ising_job_set_id = '7aec82091817425880af55e9d8e5f6f6-16667976273163059'
# ising_job_sim_id = 'dc7f791b7b6f4e6bb09e094294f41019-16660448403650491'
# job_manager = IBMQJobManager()
# ising_job_set = job_manager.retrieve_job_set(job_set_id=ising_job_sim_id, provider=provider)

# %%
counts = ising_job_set.results().combine_results().get_counts()
print(counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9a814548862b> in <module>
# ----> 1 counts = ising_job_set.results().combine_results().get_counts()
#       2 print(counts)
#
# NameError: name 'ising_job_set' is not defined

# %% [markdown]
# ## Measurement Error Mitigation
#
# Video Companion - ["Nick Knows - Measurement Errors"](https://www.youtube.com/watch?v=9ZSBkH-2zjs&list=PLOFEBzvs-VvodTtg75jH3t2levcnVlrkk&index=9) <br>
#
# This uses `mthree` (matrix-free measurement mitigation) to do $LU$-decomposition on a readout calibration routine to efficently correct for readout errors. Note that `cals_from_system` runs an experiment on your chosen `backend` and then applies it to your results to calculate quasi-probabilities, with the default `num_shots=8192`.

# %%
my_layout = [11, 8, 14, 16]

# %%
from mthree import M3Mitigation

mit = M3Mitigation(backend)
# mit.cals_from_system(my_layout)
# mit.cals_to_file('meas_cals_q{}.json'.format(my_layout))

# %%
mit.cals_from_file('meas_cals_q{}.json'.format(my_layout))

# %%
# apply the correction
quasi_probs = mit.apply_correction(counts, my_layout)

# %%
from helper import combine_twirled_data, combine_mag_data
twirled_test = combine_twirled_data(counts, num_twirls)
mag_test = combine_mag_data(twirled_test)

# %%
counts
# Out:
# [{'0000': 259,
#   '0001': 217,
#   '0010': 261,
#   '0011': 257,
#   '0100': 255,
#   '0101': 274,
#   '0110': 233,
#   '0111': 243,
#   '1000': 241,
#   '1001': 263,
#   '1010': 237,
#   '1011': 259,
#   '1100': 224,
#   '1101': 264,
#   '1110': 264,
#   '1111': 249},
#  {'0000': 252,
#   '0001': 283,
#   '0010': 252,
#   '0011': 228,
#   '0100': 234,
#   '0101': 244,
#   '0110': 227,
#   '0111': 265,
#   '1000': 260,
#   '1001': 239,
#   '1010': 236,
#   '1011': 252,
#   '1100': 244,
#   '1101': 255,
#   '1110': 248,
#   '1111': 281},
#  {'0000': 4000},
#  {'0000': 49,
#   '0001': 112,
#   '0010': 133,
#   '0011': 218,
#   '0100': 123,
#   '0101': 255,
#   '0110': 231,
#   '0111': 381,
#   '1000': 120,
#   '1001': 234,
#   '1010': 200,
#   '1011': 380,
#   '1100': 227,
#   '1101': 379,
#   '1110': 379,
#   '1111': 579},
#  {'0000': 34,
#   '0001': 63,
#   '0010': 63,
#   '0011': 152,
#   '0100': 47,
#   '0101': 172,
#   '0110': 157,
#   '0111': 412,
#   '1000': 74,
#   '1001': 156,
#   '1010': 134,
#   '1011': 387,
#   '1100': 139,
#   '1101': 385,
#   '1110': 377,
#   '1111': 1248},
#  {'0000': 2815,
#   '0001': 283,
#   '0010': 241,
#   '0011': 19,
#   '0100': 246,
#   '0101': 28,
#   '0110': 25,
#   '0111': 3,
#   '1000': 258,
#   '1001': 28,
#   '1010': 25,
#   '1011': 1,
#   '1100': 26,
#   '1110': 2},
#  {'0000': 52,
#   '0001': 11,
#   '0010': 20,
#   '0011': 102,
#   '0100': 7,
#   '0101': 78,
#   '0110': 86,
#   '0111': 494,
#   '1000': 6,
#   '1001': 85,
#   '1010': 101,
#   '1011': 488,
#   '1100': 84,
#   '1101': 493,
#   '1110': 505,
#   '1111': 1388},
#  {'0000': 61,
#   '0001': 57,
#   '0010': 70,
#   '0011': 151,
#   '0100': 55,
#   '0101': 162,
#   '0110': 156,
#   '0111': 232,
#   '1000': 68,
#   '1001': 171,
#   '1010': 148,
#   '1011': 227,
#   '1100': 180,
#   '1101': 227,
#   '1110': 206,
#   '1111': 1829},
#  {'0000': 1468,
#   '0001': 325,
#   '0010': 359,
#   '0011': 116,
#   '0100': 369,
#   '0101': 129,
#   '0110': 152,
#   '0111': 85,
#   '1000': 310,
#   '1001': 138,
#   '1010': 147,
#   '1011': 80,
#   '1100': 134,
#   '1101': 83,
#   '1110': 70,
#   '1111': 35},
#  {'0000': 127,
#   '0001': 164,
#   '0010': 169,
#   '0011': 20,
#   '0100': 172,
#   '0101': 10,
#   '0110': 10,
#   '0111': 324,
#   '1000': 194,
#   '1001': 10,
#   '1010': 12,
#   '1011': 331,
#   '1100': 15,
#   '1101': 346,
#   '1110': 311,
#   '1111': 1785},
#  {'0000': 54,
#   '0001': 194,
#   '0010': 202,
#   '0011': 77,
#   '0100': 210,
#   '0101': 84,
#   '0110': 76,
#   '0111': 447,
#   '1000': 190,
#   '1001': 77,
#   '1010': 88,
#   '1011': 401,
#   '1100': 86,
#   '1101': 386,
#   '1110': 369,
#   '1111': 1059},
#  {'0000': 989,
#   '0001': 252,
#   '0010': 258,
#   '0011': 105,
#   '0100': 233,
#   '0101': 133,
#   '0110': 121,
#   '0111': 242,
#   '1000': 233,
#   '1001': 120,
#   '1010': 103,
#   '1011': 209,
#   '1100': 140,
#   '1101': 231,
#   '1110': 270,
#   '1111': 361},
#  {'0000': 121,
#   '0001': 252,
#   '0010': 286,
#   '0011': 36,
#   '0100': 256,
#   '0101': 38,
#   '0110': 41,
#   '0111': 223,
#   '1000': 286,
#   '1001': 38,
#   '1010': 49,
#   '1011': 242,
#   '1100': 29,
#   '1101': 238,
#   '1110': 237,
#   '1111': 1628},
#  {'0000': 176,
#   '0001': 398,
#   '0010': 444,
#   '0011': 50,
#   '0100': 430,
#   '0101': 42,
#   '0110': 29,
#   '0111': 381,
#   '1000': 460,
#   '1001': 29,
#   '1010': 49,
#   '1011': 373,
#   '1100': 49,
#   '1101': 346,
#   '1110': 363,
#   '1111': 381},
#  {'0000': 1011,
#   '0001': 147,
#   '0010': 134,
#   '0011': 103,
#   '0100': 172,
#   '0101': 102,
#   '0110': 110,
#   '0111': 174,
#   '1000': 164,
#   '1001': 118,
#   '1010': 95,
#   '1011': 157,
#   '1100': 110,
#   '1101': 151,
#   '1110': 159,
#   '1111': 1093},
#  {'0000': 5,
#   '0001': 107,
#   '0010': 101,
#   '0011': 186,
#   '0100': 94,
#   '0101': 173,
#   '0110': 177,
#   '0111': 382,
#   '1000': 102,
#   '1001': 179,
#   '1010': 184,
#   '1011': 390,
#   '1100': 193,
#   '1101': 397,
#   '1110': 397,
#   '1111': 933},
#  {'0000': 1558,
#   '0001': 203,
#   '0010': 193,
#   '0011': 48,
#   '0100': 206,
#   '0101': 58,
#   '0110': 75,
#   '0111': 285,
#   '1000': 223,
#   '1001': 47,
#   '1010': 55,
#   '1011': 285,
#   '1100': 51,
#   '1101': 300,
#   '1110': 287,
#   '1111': 126},
#  {'0000': 834,
#   '0001': 196,
#   '0010': 187,
#   '0011': 156,
#   '0100': 194,
#   '0101': 167,
#   '0110': 178,
#   '0111': 14,
#   '1000': 205,
#   '1001': 174,
#   '1010': 163,
#   '1011': 20,
#   '1100': 162,
#   '1101': 16,
#   '1110': 13,
#   '1111': 1321},
#  {'0000': 303,
#   '0001': 7,
#   '0010': 15,
#   '0011': 217,
#   '0100': 13,
#   '0101': 227,
#   '0110': 230,
#   '0111': 511,
#   '1000': 15,
#   '1001': 222,
#   '1010': 237,
#   '1011': 477,
#   '1100': 229,
#   '1101': 503,
#   '1110': 508,
#   '1111': 286},
#  {'0000': 2245,
#   '0001': 119,
#   '0010': 132,
#   '0011': 75,
#   '0100': 111,
#   '0101': 91,
#   '0110': 85,
#   '0111': 189,
#   '1000': 137,
#   '1001': 64,
#   '1010': 63,
#   '1011': 190,
#   '1100': 77,
#   '1101': 187,
#   '1110': 175,
#   '1111': 60},
#  {'0000': 707,
#   '0001': 456,
#   '0010': 430,
#   '0011': 39,
#   '0100': 429,
#   '0101': 48,
#   '0110': 53,
#   '0111': 21,
#   '1000': 492,
#   '1001': 45,
#   '1010': 46,
#   '1011': 22,
#   '1100': 38,
#   '1101': 24,
#   '1110': 25,
#   '1111': 1125},
#  {'0000': 315,
#   '0001': 201,
#   '0010': 205,
#   '0011': 248,
#   '0100': 197,
#   '0101': 258,
#   '0110': 245,
#   '0111': 327,
#   '1000': 201,
#   '1001': 272,
#   '1010': 256,
#   '1011': 300,
#   '1100': 251,
#   '1101': 308,
#   '1110': 297,
#   '1111': 119},
#  {'0000': 1516,
#   '0001': 140,
#   '0010': 146,
#   '0011': 227,
#   '0100': 132,
#   '0101': 208,
#   '0110': 220,
#   '0111': 58,
#   '1000': 146,
#   '1001': 218,
#   '1010': 211,
#   '1011': 49,
#   '1100': 214,
#   '1101': 38,
#   '1110': 37,
#   '1111': 440},
#  {'0000': 1821,
#   '0001': 250,
#   '0010': 274,
#   '0011': 6,
#   '0100': 241,
#   '0101': 2,
#   '0110': 3,
#   '0111': 106,
#   '1000': 240,
#   '1001': 1,
#   '1010': 1,
#   '1011': 90,
#   '1100': 4,
#   '1101': 110,
#   '1110': 92,
#   '1111': 759},
#  {'0000': 3,
#   '0001': 342,
#   '0010': 345,
#   '0011': 244,
#   '0100': 338,
#   '0101': 259,
#   '0110': 294,
#   '0111': 162,
#   '1000': 347,
#   '1001': 270,
#   '1010': 245,
#   '1011': 159,
#   '1100': 255,
#   '1101': 147,
#   '1110': 149,
#   '1111': 441},
#  {'0000': 910,
#   '0001': 75,
#   '0010': 96,
#   '0011': 152,
#   '0100': 84,
#   '0101': 157,
#   '0110': 180,
#   '0111': 349,
#   '1000': 81,
#   '1001': 174,
#   '1010': 166,
#   '1011': 345,
#   '1100': 168,
#   '1101': 360,
#   '1110': 354,
#   '1111': 349},
#  {'0000': 2654,
#   '0001': 4,
#   '0010': 5,
#   '0011': 18,
#   '0100': 3,
#   '0101': 21,
#   '0110': 15,
#   '0111': 191,
#   '1000': 5,
#   '1001': 19,
#   '1010': 14,
#   '1011': 195,
#   '1100': 17,
#   '1101': 178,
#   '1110': 197,
#   '1111': 464},
#  {'0000': 411,
#   '0001': 248,
#   '0010': 259,
#   '0011': 116,
#   '0100': 259,
#   '0101': 86,
#   '0110': 102,
#   '0111': 225,
#   '1000': 227,
#   '1001': 122,
#   '1010': 97,
#   '1011': 255,
#   '1100': 97,
#   '1101': 238,
#   '1110': 260,
#   '1111': 998},
#  {'0000': 204,
#   '0001': 173,
#   '0010': 187,
#   '0011': 213,
#   '0100': 158,
#   '0101': 223,
#   '0110': 248,
#   '0111': 417,
#   '1000': 179,
#   '1001': 209,
#   '1010': 208,
#   '1011': 393,
#   '1100': 215,
#   '1101': 392,
#   '1110': 388,
#   '1111': 193},
#  {'0000': 2254,
#   '0001': 38,
#   '0010': 37,
#   '0011': 99,
#   '0100': 35,
#   '0101': 108,
#   '0110': 87,
#   '0111': 34,
#   '1000': 34,
#   '1001': 120,
#   '1010': 114,
#   '1011': 28,
#   '1100': 119,
#   '1101': 48,
#   '1110': 42,
#   '1111': 803},
#  {'0000': 418,
#   '0001': 75,
#   '0010': 60,
#   '0011': 41,
#   '0100': 69,
#   '0101': 42,
#   '0110': 35,
#   '0111': 472,
#   '1000': 80,
#   '1001': 43,
#   '1010': 52,
#   '1011': 425,
#   '1100': 34,
#   '1101': 431,
#   '1110': 444,
#   '1111': 1279},
#  {'0000': 61,
#   '0001': 92,
#   '0010': 85,
#   '0011': 286,
#   '0100': 96,
#   '0101': 264,
#   '0110': 291,
#   '0111': 372,
#   '1000': 89,
#   '1001': 316,
#   '1010': 281,
#   '1011': 331,
#   '1100': 292,
#   '1101': 354,
#   '1110': 347,
#   '1111': 443},
#  {'0000': 1758,
#   '0001': 75,
#   '0010': 87,
#   '0011': 137,
#   '0100': 77,
#   '0101': 143,
#   '0110': 118,
#   '0111': 76,
#   '1000': 68,
#   '1001': 108,
#   '1010': 132,
#   '1011': 92,
#   '1100': 148,
#   '1101': 70,
#   '1110': 70,
#   '1111': 841},
#  {'0000': 192,
#   '0001': 12,
#   '0010': 11,
#   '0011': 49,
#   '0100': 15,
#   '0101': 62,
#   '0110': 71,
#   '0111': 519,
#   '1000': 11,
#   '1001': 50,
#   '1010': 57,
#   '1011': 500,
#   '1100': 56,
#   '1101': 494,
#   '1110': 472,
#   '1111': 1429},
#  {'0000': 452,
#   '0001': 16,
#   '0010': 26,
#   '0011': 121,
#   '0100': 21,
#   '0101': 131,
#   '0110': 127,
#   '0111': 459,
#   '1000': 21,
#   '1001': 127,
#   '1010': 124,
#   '1011': 442,
#   '1100': 107,
#   '1101': 469,
#   '1110': 436,
#   '1111': 921},
#  {'0000': 1224,
#   '0001': 271,
#   '0010': 275,
#   '0011': 27,
#   '0100': 258,
#   '0101': 36,
#   '0110': 49,
#   '0111': 321,
#   '1000': 246,
#   '1001': 49,
#   '1010': 39,
#   '1011': 331,
#   '1100': 38,
#   '1101': 334,
#   '1110': 327,
#   '1111': 175},
#  {'0000': 151,
#   '0001': 114,
#   '0010': 105,
#   '0011': 158,
#   '0100': 118,
#   '0101': 170,
#   '0110': 177,
#   '0111': 381,
#   '1000': 119,
#   '1001': 143,
#   '1010': 159,
#   '1011': 389,
#   '1100': 164,
#   '1101': 416,
#   '1110': 385,
#   '1111': 851},
#  {'0000': 618,
#   '0001': 15,
#   '0010': 35,
#   '0011': 8,
#   '0100': 22,
#   '0101': 9,
#   '0110': 12,
#   '0111': 210,
#   '1000': 27,
#   '1001': 12,
#   '1010': 9,
#   '1011': 190,
#   '1100': 10,
#   '1101': 221,
#   '1110': 239,
#   '1111': 2363},
#  {'0000': 541,
#   '0001': 401,
#   '0010': 355,
#   '0011': 144,
#   '0100': 380,
#   '0101': 132,
#   '0110': 144,
#   '0111': 276,
#   '1000': 366,
#   '1001': 148,
#   '1010': 127,
#   '1011': 288,
#   '1100': 130,
#   '1101': 260,
#   '1110': 283,
#   '1111': 25},
#  {'0000': 261,
#   '0001': 220,
#   '0010': 246,
#   '0011': 255,
#   '0100': 250,
#   '0101': 228,
#   '0110': 250,
#   '0111': 294,
#   '1000': 249,
#   '1001': 233,
#   '1010': 241,
#   '1011': 250,
#   '1100': 250,
#   '1101': 262,
#   '1110': 263,
#   '1111': 248},
#  {'0000': 435, '0111': 2, '1011': 3, '1101': 1, '1110': 2, '1111': 3557},
#  {'0000': 245,
#   '0001': 263,
#   '0010': 264,
#   '0011': 254,
#   '0100': 267,
#   '0101': 237,
#   '0110': 267,
#   '0111': 252,
#   '1000': 266,
#   '1001': 246,
#   '1010': 269,
#   '1011': 276,
#   '1100': 221,
#   '1101': 207,
#   '1110': 245,
#   '1111': 221},
#  {'0000': 587,
#   '0001': 327,
#   '0010': 325,
#   '0011': 196,
#   '0100': 303,
#   '0101': 224,
#   '0110': 191,
#   '0111': 180,
#   '1000': 300,
#   '1001': 208,
#   '1010': 202,
#   '1011': 189,
#   '1100': 217,
#   '1101': 178,
#   '1110': 171,
#   '1111': 202},
#  {'0000': 274,
#   '0001': 64,
#   '0010': 50,
#   '0011': 3,
#   '0100': 50,
#   '0101': 2,
#   '0110': 7,
#   '0111': 80,
#   '1000': 54,
#   '1001': 3,
#   '1010': 3,
#   '1011': 78,
#   '1100': 3,
#   '1101': 75,
#   '1110': 71,
#   '1111': 3183},
#  {'0000': 230,
#   '0001': 141,
#   '0010': 145,
#   '0011': 187,
#   '0100': 123,
#   '0101': 167,
#   '0110': 162,
#   '0111': 447,
#   '1000': 160,
#   '1001': 141,
#   '1010': 188,
#   '1011': 478,
#   '1100': 180,
#   '1101': 446,
#   '1110': 472,
#   '1111': 333},
#  {'0000': 1066,
#   '0001': 342,
#   '0010': 328,
#   '0011': 111,
#   '0100': 355,
#   '0101': 108,
#   '0110': 110,
#   '0111': 156,
#   '1000': 383,
#   '1001': 109,
#   '1010': 73,
#   '1011': 151,
#   '1100': 101,
#   '1101': 155,
#   '1110': 130,
#   '1111': 322},
#  {'0000': 364,
#   '0001': 186,
#   '0010': 166,
#   '0011': 35,
#   '0100': 208,
#   '0101': 39,
#   '0110': 41,
#   '0111': 134,
#   '1000': 203,
#   '1001': 34,
#   '1010': 45,
#   '1011': 167,
#   '1100': 41,
#   '1101': 177,
#   '1110': 191,
#   '1111': 1969},
#  {'0000': 245,
#   '0001': 87,
#   '0010': 85,
#   '0011': 46,
#   '0100': 88,
#   '0101': 40,
#   '0110': 50,
#   '0111': 669,
#   '1000': 76,
#   '1001': 41,
#   '1010': 30,
#   '1011': 686,
#   '1100': 31,
#   '1101': 687,
#   '1110': 715,
#   '1111': 424},
#  {'0000': 1240,
#   '0001': 323,
#   '0010': 301,
#   '0011': 26,
#   '0100': 313,
#   '0101': 28,
#   '0110': 32,
#   '0111': 168,
#   '1000': 306,
#   '1001': 40,
#   '1010': 31,
#   '1011': 197,
#   '1100': 31,
#   '1101': 186,
#   '1110': 181,
#   '1111': 597},
#  {'0000': 919,
#   '0001': 353,
#   '0010': 336,
#   '0011': 53,
#   '0100': 368,
#   '0101': 50,
#   '0110': 65,
#   '0111': 144,
#   '1000': 357,
#   '1001': 41,
#   '1010': 55,
#   '1011': 118,
#   '1100': 56,
#   '1101': 130,
#   '1110': 118,
#   '1111': 837},
#  {'0000': 265,
#   '0001': 35,
#   '0010': 43,
#   '0011': 4,
#   '0100': 33,
#   '0101': 5,
#   '0110': 2,
#   '0111': 806,
#   '1000': 32,
#   '1001': 6,
#   '1010': 8,
#   '1011': 833,
#   '1100': 3,
#   '1101': 819,
#   '1110': 804,
#   '1111': 302},
#  {'0000': 747,
#   '0001': 226,
#   '0010': 223,
#   '0011': 52,
#   '0100': 215,
#   '0101': 55,
#   '0110': 51,
#   '0111': 290,
#   '1000': 218,
#   '1001': 60,
#   '1010': 54,
#   '1011': 272,
#   '1100': 57,
#   '1101': 292,
#   '1110': 262,
#   '1111': 926},
#  {'0000': 1899,
#   '0001': 428,
#   '0010': 433,
#   '0011': 7,
#   '0100': 455,
#   '0101': 8,
#   '0110': 6,
#   '0111': 39,
#   '1000': 435,
#   '1001': 5,
#   '1010': 8,
#   '1011': 46,
#   '1100': 5,
#   '1101': 32,
#   '1110': 35,
#   '1111': 159},
#  {'0000': 135,
#   '0001': 9,
#   '0010': 8,
#   '0011': 80,
#   '0100': 6,
#   '0101': 67,
#   '0110': 62,
#   '0111': 754,
#   '1000': 9,
#   '1001': 72,
#   '1010': 77,
#   '1011': 764,
#   '1100': 99,
#   '1101': 733,
#   '1110': 746,
#   '1111': 379},
#  {'0000': 22,
#   '0001': 75,
#   '0010': 103,
#   '0011': 183,
#   '0100': 84,
#   '0101': 157,
#   '0110': 169,
#   '0111': 419,
#   '1000': 82,
#   '1001': 159,
#   '1010': 149,
#   '1011': 411,
#   '1100': 148,
#   '1101': 418,
#   '1110': 427,
#   '1111': 994},
#  {'0000': 2227,
#   '0001': 299,
#   '0010': 323,
#   '0011': 44,
#   '0100': 317,
#   '0101': 46,
#   '0110': 48,
#   '0111': 36,
#   '1000': 319,
#   '1001': 46,
#   '1010': 33,
#   '1011': 20,
#   '1100': 42,
#   '1101': 34,
#   '1110': 32,
#   '1111': 134},
#  {'0000': 124,
#   '0001': 24,
#   '0010': 17,
#   '0011': 136,
#   '0100': 21,
#   '0101': 152,
#   '0110': 131,
#   '0111': 432,
#   '1000': 13,
#   '1001': 151,
#   '1010': 132,
#   '1011': 435,
#   '1100': 156,
#   '1101': 440,
#   '1110': 465,
#   '1111': 1171},
#  {'0000': 440,
#   '0001': 42,
#   '0010': 27,
#   '0011': 129,
#   '0100': 41,
#   '0101': 144,
#   '0110': 160,
#   '0111': 481,
#   '1000': 36,
#   '1001': 135,
#   '1010': 127,
#   '1011': 456,
#   '1100': 142,
#   '1101': 484,
#   '1110': 451,
#   '1111': 705},
#  {'0000': 1226,
#   '0001': 382,
#   '0010': 405,
#   '0011': 146,
#   '0100': 392,
#   '0101': 158,
#   '0110': 154,
#   '0111': 46,
#   '1000': 397,
#   '1001': 159,
#   '1010': 158,
#   '1011': 32,
#   '1100': 157,
#   '1101': 30,
#   '1110': 37,
#   '1111': 121},
#  {'0000': 321,
#   '0001': 75,
#   '0010': 75,
#   '0011': 125,
#   '0100': 71,
#   '0101': 115,
#   '0110': 108,
#   '0111': 193,
#   '1000': 69,
#   '1001': 93,
#   '1010': 111,
#   '1011': 191,
#   '1100': 83,
#   '1101': 189,
#   '1110': 169,
#   '1111': 2012},
#  {'0000': 835,
#   '0001': 107,
#   '0010': 122,
#   '0011': 70,
#   '0100': 121,
#   '0101': 67,
#   '0110': 65,
#   '0111': 396,
#   '1000': 103,
#   '1001': 88,
#   '1010': 77,
#   '1011': 392,
#   '1100': 74,
#   '1101': 374,
#   '1110': 375,
#   '1111': 734},
#  {'0000': 329,
#   '0001': 684,
#   '0010': 748,
#   '0011': 117,
#   '0100': 704,
#   '0101': 113,
#   '0110': 136,
#   '0111': 17,
#   '1000': 701,
#   '1001': 136,
#   '1010': 129,
#   '1011': 22,
#   '1100': 126,
#   '1101': 23,
#   '1110': 15},
#  {'0000': 386,
#   '0001': 125,
#   '0010': 145,
#   '0011': 33,
#   '0100': 137,
#   '0101': 29,
#   '0110': 28,
#   '0111': 156,
#   '1000': 133,
#   '1001': 28,
#   '1010': 38,
#   '1011': 167,
#   '1100': 32,
#   '1101': 176,
#   '1110': 193,
#   '1111': 2194},
#  {'0000': 153,
#   '0001': 265,
#   '0010': 267,
#   '0011': 68,
#   '0100': 275,
#   '0101': 50,
#   '0110': 54,
#   '0111': 228,
#   '1000': 298,
#   '1001': 56,
#   '1010': 62,
#   '1011': 205,
#   '1100': 72,
#   '1101': 228,
#   '1110': 212,
#   '1111': 1507},
#  {'0000': 62,
#   '0001': 658,
#   '0010': 658,
#   '0011': 144,
#   '0100': 620,
#   '0101': 131,
#   '0110': 152,
#   '0111': 121,
#   '1000': 650,
#   '1001': 136,
#   '1010': 122,
#   '1011': 104,
#   '1100': 123,
#   '1101': 114,
#   '1110': 105,
#   '1111': 100},
#  {'0000': 197,
#   '0001': 133,
#   '0010': 125,
#   '0011': 44,
#   '0100': 143,
#   '0101': 39,
#   '0110': 48,
#   '0111': 120,
#   '1000': 138,
#   '1001': 60,
#   '1010': 39,
#   '1011': 127,
#   '1100': 43,
#   '1101': 128,
#   '1110': 127,
#   '1111': 2489},
#  {'0000': 276,
#   '0001': 324,
#   '0010': 336,
#   '0011': 52,
#   '0100': 314,
#   '0101': 69,
#   '0110': 63,
#   '0111': 166,
#   '1000': 342,
#   '1001': 49,
#   '1010': 61,
#   '1011': 183,
#   '1100': 67,
#   '1101': 191,
#   '1110': 177,
#   '1111': 1330},
#  {'0000': 34,
#   '0001': 318,
#   '0010': 343,
#   '0011': 281,
#   '0100': 349,
#   '0101': 282,
#   '0110': 286,
#   '0111': 176,
#   '1000': 366,
#   '1001': 281,
#   '1010': 283,
#   '1011': 173,
#   '1100': 308,
#   '1101': 192,
#   '1110': 183,
#   '1111': 145},
#  {'0000': 40,
#   '0001': 61,
#   '0010': 54,
#   '0011': 95,
#   '0100': 45,
#   '0101': 83,
#   '0110': 104,
#   '0111': 52,
#   '1000': 59,
#   '1001': 89,
#   '1010': 100,
#   '1011': 44,
#   '1100': 89,
#   '1101': 35,
#   '1110': 55,
#   '1111': 2995},
#  {'0000': 647,
#   '0001': 224,
#   '0010': 227,
#   '0011': 105,
#   '0100': 213,
#   '0101': 98,
#   '0110': 104,
#   '0111': 291,
#   '1000': 195,
#   '1001': 109,
#   '1010': 100,
#   '1011': 285,
#   '1100': 99,
#   '1101': 282,
#   '1110': 301,
#   '1111': 720},
#  {'0000': 292,
#   '0001': 347,
#   '0010': 310,
#   '0011': 277,
#   '0100': 373,
#   '0101': 287,
#   '0110': 307,
#   '0111': 126,
#   '1000': 314,
#   '1001': 312,
#   '1010': 288,
#   '1011': 104,
#   '1100': 278,
#   '1101': 115,
#   '1110': 112,
#   '1111': 158},
#  {'0000': 4,
#   '0010': 7,
#   '0011': 57,
#   '0100': 4,
#   '0101': 68,
#   '0110': 47,
#   '0111': 116,
#   '1000': 7,
#   '1001': 64,
#   '1010': 62,
#   '1011': 112,
#   '1100': 69,
#   '1101': 109,
#   '1110': 110,
#   '1111': 3164},
#  {'0000': 212,
#   '0001': 150,
#   '0010': 150,
#   '0011': 203,
#   '0100': 156,
#   '0101': 203,
#   '0110': 206,
#   '0111': 354,
#   '1000': 154,
#   '1001': 183,
#   '1010': 199,
#   '1011': 343,
#   '1100': 217,
#   '1101': 365,
#   '1110': 370,
#   '1111': 535},
#  {'0000': 386,
#   '0001': 327,
#   '0010': 381,
#   '0011': 219,
#   '0100': 378,
#   '0101': 228,
#   '0110': 221,
#   '0111': 164,
#   '1000': 350,
#   '1001': 217,
#   '1010': 210,
#   '1011': 146,
#   '1100': 216,
#   '1101': 173,
#   '1110': 161,
#   '1111': 223},
#  {'0000': 2,
#   '0011': 17,
#   '0101': 9,
#   '0110': 22,
#   '0111': 105,
#   '1001': 27,
#   '1010': 17,
#   '1011': 108,
#   '1100': 16,
#   '1101': 91,
#   '1110': 118,
#   '1111': 3468},
#  {'0000': 96,
#   '0001': 175,
#   '0010': 179,
#   '0011': 248,
#   '0100': 170,
#   '0101': 241,
#   '0110': 258,
#   '0111': 318,
#   '1000': 194,
#   '1001': 221,
#   '1010': 248,
#   '1011': 321,
#   '1100': 260,
#   '1101': 315,
#   '1110': 349,
#   '1111': 407},
#  {'0000': 245,
#   '0001': 224,
#   '0010': 245,
#   '0011': 234,
#   '0100': 246,
#   '0101': 227,
#   '0110': 254,
#   '0111': 243,
#   '1000': 267,
#   '1001': 211,
#   '1010': 247,
#   '1011': 271,
#   '1100': 233,
#   '1101': 250,
#   '1110': 278,
#   '1111': 325},
#  {'0011': 1,
#   '0101': 1,
#   '0110': 2,
#   '0111': 19,
#   '1001': 2,
#   '1010': 2,
#   '1011': 25,
#   '1100': 1,
#   '1101': 17,
#   '1110': 21,
#   '1111': 3909},
#  {'0000': 269,
#   '0001': 241,
#   '0010': 241,
#   '0011': 241,
#   '0100': 270,
#   '0101': 260,
#   '0110': 224,
#   '0111': 256,
#   '1000': 250,
#   '1001': 241,
#   '1010': 252,
#   '1011': 262,
#   '1100': 256,
#   '1101': 255,
#   '1110': 261,
#   '1111': 221},
#  {'0000': 257,
#   '0001': 253,
#   '0010': 254,
#   '0011': 254,
#   '0100': 244,
#   '0101': 221,
#   '0110': 242,
#   '0111': 256,
#   '1000': 258,
#   '1001': 222,
#   '1010': 261,
#   '1011': 284,
#   '1100': 256,
#   '1101': 237,
#   '1110': 257,
#   '1111': 244},
#  {'1111': 4000},
#  {'0000': 225,
#   '0001': 215,
#   '0010': 257,
#   '0011': 257,
#   '0100': 240,
#   '0101': 275,
#   '0110': 260,
#   '0111': 251,
#   '1000': 250,
#   '1001': 253,
#   '1010': 264,
#   '1011': 282,
#   '1100': 273,
#   '1101': 255,
#   '1110': 229,
#   '1111': 214},
#  {'0000': 253,
#   '0001': 264,
#   '0010': 236,
#   '0011': 261,
#   '0100': 234,
#   '0101': 252,
#   '0110': 264,
#   '0111': 239,
#   '1000': 245,
#   '1001': 250,
#   '1010': 231,
#   '1011': 245,
#   '1100': 239,
#   '1101': 252,
#   '1110': 249,
#   '1111': 286},
#  {'0011': 1, '1001': 1, '1010': 1, '1100': 1, '1111': 3996},
#  {'0000': 150,
#   '0001': 231,
#   '0010': 245,
#   '0011': 273,
#   '0100': 242,
#   '0101': 306,
#   '0110': 270,
#   '0111': 244,
#   '1000': 230,
#   '1001': 236,
#   '1010': 264,
#   '1011': 285,
#   '1100': 268,
#   '1101': 257,
#   '1110': 265,
#   '1111': 234},
#  {'0000': 143,
#   '0001': 195,
#   '0010': 179,
#   '0011': 265,
#   '0100': 174,
#   '0101': 203,
#   '0110': 239,
#   '0111': 293,
#   '1000': 194,
#   '1001': 246,
#   '1010': 230,
#   '1011': 301,
#   '1100': 224,
#   '1101': 291,
#   '1110': 293,
#   '1111': 530},
#  {'0001': 1,
#   '0010': 2,
#   '0011': 2,
#   '0100': 2,
#   '0101': 4,
#   '0110': 2,
#   '0111': 18,
#   '1000': 1,
#   '1001': 2,
#   '1010': 5,
#   '1011': 12,
#   '1100': 1,
#   '1101': 18,
#   '1110': 19,
#   '1111': 3911},
#  {'0000': 193,
#   '0001': 234,
#   '0010': 248,
#   '0011': 271,
#   '0100': 278,
#   '0101': 264,
#   '0110': 242,
#   '0111': 234,
#   '1000': 265,
#   '1001': 242,
#   '1010': 239,
#   '1011': 265,
#   '1100': 251,
#   '1101': 262,
#   '1110': 258,
#   '1111': 254},
#  {'0000': 52,
#   '0001': 148,
#   '0010': 153,
#   '0011': 258,
#   '0100': 144,
#   '0101': 218,
#   '0110': 213,
#   '0111': 334,
#   '1000': 138,
#   '1001': 239,
#   '1010': 225,
#   '1011': 312,
#   '1100': 220,
#   '1101': 300,
#   '1110': 292,
#   '1111': 754},
#  {'0000': 21,
#   '0001': 8,
#   '0010': 9,
#   '0011': 1,
#   '0100': 12,
#   '0110': 1,
#   '0111': 76,
#   '1000': 10,
#   '1001': 1,
#   '1010': 2,
#   '1011': 79,
#   '1100': 1,
#   '1101': 60,
#   '1110': 64,
#   '1111': 3655},
#  {'0000': 184,
#   '0001': 210,
#   '0010': 230,
#   '0011': 265,
#   '0100': 219,
#   '0101': 259,
#   '0110': 263,
#   '0111': 271,
#   '1000': 246,
#   '1001': 272,
#   '1010': 252,
#   '1011': 248,
#   '1100': 273,
#   '1101': 273,
#   '1110': 261,
#   '1111': 274},
#  {'0000': 67,
#   '0001': 168,
#   '0010': 182,
#   '0011': 239,
#   '0100': 183,
#   '0101': 235,
#   '0110': 230,
#   '0111': 263,
#   '1000': 190,
#   '1001': 253,
#   '1010': 238,
#   '1011': 281,
#   '1100': 221,
#   '1101': 268,
#   '1110': 236,
#   '1111': 746},
#  {'0000': 198,
#   '0001': 14,
#   '0010': 19,
#   '0011': 2,
#   '0100': 13,
#   '0101': 2,
#   '0111': 50,
#   '1000': 9,
#   '1010': 3,
#   '1011': 40,
#   '1100': 3,
#   '1101': 36,
#   '1110': 37,
#   '1111': 3574},
#  {'0000': 156,
#   '0001': 240,
#   '0010': 238,
#   '0011': 272,
#   '0100': 229,
#   '0101': 286,
#   '0110': 273,
#   '0111': 256,
#   '1000': 227,
#   '1001': 259,
#   '1010': 269,
#   '1011': 229,
#   '1100': 305,
#   '1101': 264,
#   '1110': 286,
#   '1111': 211},
#  {'0000': 255,
#   '0001': 242,
#   '0010': 277,
#   '0011': 249,
#   '0100': 269,
#   '0101': 220,
#   '0110': 220,
#   '0111': 248,
#   '1000': 309,
#   '1001': 219,
#   '1010': 222,
#   '1011': 208,
#   '1100': 205,
#   '1101': 220,
#   '1110': 222,
#   '1111': 415},
#  {'0000': 488,
#   '0001': 9,
#   '0010': 6,
#   '0011': 1,
#   '0100': 8,
#   '0101': 4,
#   '0110': 3,
#   '1000': 7,
#   '1001': 4,
#   '1010': 2,
#   '1100': 3,
#   '1111': 3465},
#  {'0000': 181,
#   '0001': 280,
#   '0010': 299,
#   '0011': 204,
#   '0100': 276,
#   '0101': 225,
#   '0110': 211,
#   '0111': 205,
#   '1000': 264,
#   '1001': 225,
#   '1010': 213,
#   '1011': 229,
#   '1100': 212,
#   '1101': 238,
#   '1110': 246,
#   '1111': 492},
#  {'0000': 779,
#   '0001': 345,
#   '0010': 313,
#   '0011': 242,
#   '0100': 315,
#   '0101': 193,
#   '0110': 233,
#   '0111': 144,
#   '1000': 304,
#   '1001': 213,
#   '1010': 246,
#   '1011': 147,
#   '1100': 214,
#   '1101': 130,
#   '1110': 150,
#   '1111': 32},
#  {'0000': 720,
#   '0001': 11,
#   '0010': 7,
#   '0011': 19,
#   '0100': 7,
#   '0101': 23,
#   '0110': 16,
#   '0111': 110,
#   '1000': 14,
#   '1001': 16,
#   '1010': 20,
#   '1011': 93,
#   '1100': 18,
#   '1101': 93,
#   '1110': 88,
#   '1111': 2745},
#  {'0000': 435,
#   '0001': 263,
#   '0010': 282,
#   '0011': 118,
#   '0100': 254,
#   '0101': 110,
#   '0110': 121,
#   '0111': 229,
#   '1000': 256,
#   '1001': 104,
#   '1010': 122,
#   '1011': 241,
#   '1100': 99,
#   '1101': 244,
#   '1110': 243,
#   '1111': 879},
#  {'0000': 1363,
#   '0001': 151,
#   '0010': 177,
#   '0011': 263,
#   '0100': 135,
#   '0101': 264,
#   '0110': 249,
#   '0111': 68,
#   '1000': 158,
#   '1001': 252,
#   '1010': 264,
#   '1011': 69,
#   '1100': 261,
#   '1101': 74,
#   '1110': 63,
#   '1111': 189},
#  {'0000': 538,
#   '0001': 136,
#   '0010': 129,
#   '0011': 80,
#   '0100': 127,
#   '0101': 78,
#   '0110': 84,
#   '0111': 270,
#   '1000': 124,
#   '1001': 90,
#   '1010': 82,
#   '1011': 261,
#   '1100': 81,
#   '1101': 266,
#   '1110': 269,
#   '1111': 1385},
#  {'0000': 787,
#   '0001': 222,
#   '0010': 229,
#   '0011': 38,
#   '0100': 210,
#   '0101': 38,
#   '0110': 26,
#   '0111': 290,
#   '1000': 226,
#   '1001': 32,
#   '1010': 33,
#   '1011': 277,
#   '1100': 27,
#   '1101': 279,
#   '1110': 259,
#   '1111': 1027},
#  {'0000': 1743,
#   '0001': 66,
#   '0010': 64,
#   '0011': 188,
#   '0100': 71,
#   '0101': 173,
#   '0110': 209,
#   '0111': 48,
#   '1000': 72,
#   '1001': 203,
#   '1010': 216,
#   '1011': 54,
#   '1100': 200,
#   '1101': 50,
#   '1110': 55,
#   '1111': 588},
#  {'0000': 245,
#   '0001': 287,
#   '0010': 296,
#   '0011': 163,
#   '0100': 298,
#   '0101': 146,
#   '0110': 138,
#   '0111': 324,
#   '1000': 324,
#   '1001': 142,
#   '1010': 145,
#   '1011': 282,
#   '1100': 142,
#   '1101': 352,
#   '1110': 317,
#   '1111': 399},
#  {'0000': 682,
#   '0001': 267,
#   '0010': 258,
#   '0011': 20,
#   '0100': 272,
#   '0101': 23,
#   '0110': 21,
#   '0111': 221,
#   '1000': 265,
#   '1001': 25,
#   '1010': 18,
#   '1011': 218,
#   '1100': 27,
#   '1101': 235,
#   '1110': 239,
#   '1111': 1209},
#  {'0000': 1574,
#   '0001': 197,
#   '0010': 209,
#   '0011': 88,
#   '0100': 179,
#   '0101': 115,
#   '0110': 106,
#   '0111': 164,
#   '1000': 213,
#   '1001': 116,
#   '1010': 120,
#   '1011': 147,
#   '1100': 123,
#   '1101': 149,
#   '1110': 158,
#   '1111': 342},
#  {'0000': 523,
#   '0001': 252,
#   '0010': 300,
#   '0011': 208,
#   '0100': 297,
#   '0101': 189,
#   '0110': 199,
#   '0111': 217,
#   '1000': 267,
#   '1001': 186,
#   '1010': 162,
#   '1011': 227,
#   '1100': 192,
#   '1101': 215,
#   '1110': 236,
#   '1111': 330},
#  {'0000': 448,
#   '0001': 278,
#   '0010': 274,
#   '0011': 85,
#   '0100': 269,
#   '0101': 74,
#   '0110': 80,
#   '0111': 232,
#   '1000': 277,
#   '1001': 77,
#   '1010': 65,
#   '1011': 223,
#   '1100': 81,
#   '1101': 185,
#   '1110': 224,
#   '1111': 1128},
#  {'0000': 1021,
#   '0001': 284,
#   '0010': 288,
#   '0011': 48,
#   '0100': 241,
#   '0101': 66,
#   '0110': 48,
#   '0111': 297,
#   '1000': 275,
#   '1001': 45,
#   '1010': 37,
#   '1011': 306,
#   '1100': 51,
#   '1101': 320,
#   '1110': 334,
#   '1111': 339},
#  {'0000': 1059,
#   '0001': 97,
#   '0010': 98,
#   '0011': 236,
#   '0100': 90,
#   '0101': 234,
#   '0110': 228,
#   '0111': 81,
#   '1000': 90,
#   '1001': 265,
#   '1010': 255,
#   '1011': 88,
#   '1100': 241,
#   '1101': 93,
#   '1110': 90,
#   '1111': 755},
#  {'0000': 311,
#   '0001': 210,
#   '0010': 202,
#   '0011': 154,
#   '0100': 237,
#   '0101': 164,
#   '0110': 145,
#   '0111': 279,
#   '1000': 212,
#   '1001': 140,
#   '1010': 150,
#   '1011': 291,
#   '1100': 171,
#   '1101': 279,
#   '1110': 308,
#   '1111': 747},
#  {'0000': 562,
#   '0001': 200,
#   '0010': 223,
#   '0011': 18,
#   '0100': 220,
#   '0101': 15,
#   '0110': 17,
#   '0111': 299,
#   '1000': 180,
#   '1001': 16,
#   '1010': 20,
#   '1011': 304,
#   '1100': 11,
#   '1101': 307,
#   '1110': 295,
#   '1111': 1313},
#  {'0000': 1132,
#   '0001': 45,
#   '0010': 42,
#   '0011': 277,
#   '0100': 39,
#   '0101': 294,
#   '0110': 283,
#   '0111': 44,
#   '1000': 40,
#   '1001': 255,
#   '1010': 275,
#   '1011': 56,
#   '1100': 260,
#   '1101': 58,
#   '1110': 46,
#   '1111': 854},
#  {'0000': 278,
#   '0001': 125,
#   '0010': 105,
#   '0011': 234,
#   '0100': 117,
#   '0101': 236,
#   '0110': 218,
#   '0111': 363,
#   '1000': 128,
#   '1001': 233,
#   '1010': 229,
#   '1011': 341,
#   '1100': 238,
#   '1101': 360,
#   '1110': 393,
#   '1111': 402},
#  {'0000': 686,
#   '0001': 106,
#   '0010': 113,
#   '0011': 2,
#   '0100': 93,
#   '0101': 2,
#   '0110': 4,
#   '0111': 120,
#   '1000': 73,
#   '1010': 2,
#   '1011': 121,
#   '1100': 2,
#   '1101': 117,
#   '1110': 139,
#   '1111': 2420},
#  {'0000': 652,
#   '0001': 162,
#   '0010': 129,
#   '0011': 226,
#   '0100': 152,
#   '0101': 254,
#   '0110': 246,
#   '0111': 173,
#   '1000': 161,
#   '1001': 289,
#   '1010': 257,
#   '1011': 159,
#   '1100': 276,
#   '1101': 157,
#   '1110': 173,
#   '1111': 534},
#  {'0000': 209,
#   '0001': 198,
#   '0010': 209,
#   '0011': 254,
#   '0100': 194,
#   '0101': 264,
#   '0110': 278,
#   '0111': 294,
#   '1000': 218,
#   '1001': 256,
#   '1010': 259,
#   '1011': 288,
#   '1100': 263,
#   '1101': 294,
#   '1110': 303,
#   '1111': 219},
#  {'0000': 1029,
#   '0001': 4,
#   '0010': 4,
#   '0100': 6,
#   '0101': 2,
#   '0110': 4,
#   '0111': 3,
#   '1000': 5,
#   '1011': 7,
#   '1100': 3,
#   '1101': 8,
#   '1110': 6,
#   '1111': 2919},
#  {'0000': 321,
#   '0001': 244,
#   '0010': 241,
#   '0011': 241,
#   '0100': 252,
#   '0101': 242,
#   '0110': 237,
#   '0111': 205,
#   '1000': 221,
#   '1001': 218,
#   '1010': 213,
#   '1011': 266,
#   '1100': 235,
#   '1101': 251,
#   '1110': 255,
#   '1111': 358},
#  {'0000': 145,
#   '0001': 387,
#   '0010': 352,
#   '0011': 282,
#   '0100': 350,
#   '0101': 280,
#   '0110': 273,
#   '0111': 122,
#   '1000': 362,
#   '1001': 317,
#   '1010': 297,
#   '1011': 123,
#   '1100': 291,
#   '1101': 138,
#   '1110': 127,
#   '1111': 154},
#  {'0000': 1294,
#   '0001': 30,
#   '0010': 27,
#   '0011': 7,
#   '0100': 28,
#   '0101': 11,
#   '0110': 8,
#   '0111': 49,
#   '1000': 28,
#   '1001': 4,
#   '1010': 7,
#   '1011': 24,
#   '1100': 12,
#   '1101': 33,
#   '1110': 41,
#   '1111': 2397},
#  {'0000': 630,
#   '0001': 212,
#   '0010': 223,
#   '0011': 219,
#   '0100': 244,
#   '0101': 177,
#   '0110': 196,
#   '0111': 252,
#   '1000': 238,
#   '1001': 190,
#   '1010': 222,
#   '1011': 214,
#   '1100': 209,
#   '1101': 213,
#   '1110': 202,
#   '1111': 359},
#  {'0000': 91,
#   '0001': 434,
#   '0010': 409,
#   '0011': 283,
#   '0100': 445,
#   '0101': 280,
#   '0110': 328,
#   '0111': 46,
#   '1000': 420,
#   '1001': 336,
#   '1010': 284,
#   '1011': 67,
#   '1100': 321,
#   '1101': 63,
#   '1110': 55,
#   '1111': 138},
#  {'0000': 1303,
#   '0001': 85,
#   '0010': 88,
#   '0011': 16,
#   '0100': 82,
#   '0101': 11,
#   '0110': 18,
#   '0111': 185,
#   '1000': 74,
#   '1001': 10,
#   '1010': 21,
#   '1011': 182,
#   '1100': 22,
#   '1101': 179,
#   '1110': 181,
#   '1111': 1543},
#  {'0000': 1582,
#   '0001': 160,
#   '0010': 123,
#   '0011': 160,
#   '0100': 122,
#   '0101': 175,
#   '0110': 202,
#   '0111': 106,
#   '1000': 117,
#   '1001': 184,
#   '1010': 170,
#   '1011': 130,
#   '1100': 159,
#   '1101': 126,
#   '1110': 123,
#   '1111': 361},
#  {'0000': 71,
#   '0001': 368,
#   '0010': 400,
#   '0011': 292,
#   '0100': 435,
#   '0101': 265,
#   '0110': 302,
#   '0111': 82,
#   '1000': 425,
#   '1001': 326,
#   '1010': 305,
#   '1011': 88,
#   '1100': 311,
#   '1101': 91,
#   '1110': 96,
#   '1111': 143},
#  {'0000': 1153,
#   '0001': 107,
#   '0010': 125,
#   '0011': 35,
#   '0100': 117,
#   '0101': 33,
#   '0110': 44,
#   '0111': 303,
#   '1000': 143,
#   '1001': 40,
#   '1010': 30,
#   '1011': 312,
#   '1100': 47,
#   '1101': 296,
#   '1110': 285,
#   '1111': 930},
#  {'0000': 2447,
#   '0001': 37,
#   '0010': 44,
#   '0011': 129,
#   '0100': 48,
#   '0101': 140,
#   '0110': 140,
#   '0111': 82,
#   '1000': 50,
#   '1001': 144,
#   '1010': 132,
#   '1011': 76,
#   '1100': 135,
#   '1101': 70,
#   '1110': 73,
#   '1111': 253},
#  {'0000': 17,
#   '0001': 332,
#   '0010': 353,
#   '0011': 297,
#   '0100': 333,
#   '0101': 314,
#   '0110': 291,
#   '0111': 159,
#   '1000': 354,
#   '1001': 298,
#   '1010': 287,
#   '1011': 155,
#   '1100': 296,
#   '1101': 153,
#   '1110': 170,
#   '1111': 191},
#  {'0000': 916,
#   '0001': 117,
#   '0010': 130,
#   '0011': 59,
#   '0100': 147,
#   '0101': 76,
#   '0110': 67,
#   '0111': 375,
#   '1000': 117,
#   '1001': 76,
#   '1010': 81,
#   '1011': 380,
#   '1100': 70,
#   '1101': 406,
#   '1110': 375,
#   '1111': 608},
#  {'0000': 3092,
#   '0001': 10,
#   '0010': 18,
#   '0011': 100,
#   '0100': 23,
#   '0101': 82,
#   '0110': 103,
#   '0111': 42,
#   '1000': 18,
#   '1001': 73,
#   '1010': 88,
#   '1011': 45,
#   '1100': 87,
#   '1101': 43,
#   '1110': 49,
#   '1111': 127},
#  {'0000': 10,
#   '0001': 316,
#   '0010': 277,
#   '0011': 285,
#   '0100': 259,
#   '0101': 292,
#   '0110': 288,
#   '0111': 200,
#   '1000': 286,
#   '1001': 313,
#   '1010': 325,
#   '1011': 245,
#   '1100': 271,
#   '1101': 194,
#   '1110': 183,
#   '1111': 256},
#  {'0000': 619,
#   '0001': 148,
#   '0010': 157,
#   '0011': 115,
#   '0100': 147,
#   '0101': 139,
#   '0110': 118,
#   '0111': 396,
#   '1000': 136,
#   '1001': 153,
#   '1010': 125,
#   '1011': 360,
#   '1100': 137,
#   '1101': 400,
#   '1110': 388,
#   '1111': 462},
#  {'0000': 3516,
#   '0001': 14,
#   '0010': 5,
#   '0011': 56,
#   '0100': 12,
#   '0101': 62,
#   '0110': 46,
#   '0111': 30,
#   '1000': 16,
#   '1001': 43,
#   '1010': 40,
#   '1011': 22,
#   '1100': 50,
#   '1101': 20,
#   '1110': 19,
#   '1111': 49},
#  {'0000': 78,
#   '0001': 299,
#   '0010': 297,
#   '0011': 258,
#   '0100': 317,
#   '0101': 264,
#   '0110': 256,
#   '0111': 234,
#   '1000': 297,
#   '1001': 270,
#   '1010': 264,
#   '1011': 203,
#   '1100': 240,
#   '1101': 214,
#   '1110': 202,
#   '1111': 307},
#  {'0000': 426,
#   '0001': 176,
#   '0010': 200,
#   '0011': 194,
#   '0100': 177,
#   '0101': 192,
#   '0110': 212,
#   '0111': 337,
#   '1000': 186,
#   '1001': 190,
#   '1010': 196,
#   '1011': 352,
#   '1100': 205,
#   '1101': 309,
#   '1110': 359,
#   '1111': 289},
#  {'0000': 3814,
#   '0010': 4,
#   '0011': 14,
#   '0100': 3,
#   '0101': 20,
#   '0110': 12,
#   '0111': 14,
#   '1000': 6,
#   '1001': 17,
#   '1010': 13,
#   '1011': 18,
#   '1100': 15,
#   '1101': 17,
#   '1110': 12,
#   '1111': 21},
#  {'0000': 303,
#   '0001': 327,
#   '0010': 327,
#   '0011': 240,
#   '0100': 293,
#   '0101': 233,
#   '0110': 244,
#   '0111': 193,
#   '1000': 295,
#   '1001': 254,
#   '1010': 247,
#   '1011': 163,
#   '1100': 247,
#   '1101': 159,
#   '1110': 176,
#   '1111': 299},
#  {'0000': 316,
#   '0001': 219,
#   '0010': 228,
#   '0011': 213,
#   '0100': 245,
#   '0101': 269,
#   '0110': 226,
#   '0111': 282,
#   '1000': 221,
#   '1001': 274,
#   '1010': 281,
#   '1011': 270,
#   '1100': 233,
#   '1101': 249,
#   '1110': 255,
#   '1111': 219},
#  {'0000': 3929,
#   '0001': 7,
#   '0010': 6,
#   '0011': 2,
#   '0100': 6,
#   '0110': 2,
#   '0111': 9,
#   '1000': 7,
#   '1001': 4,
#   '1010': 2,
#   '1011': 6,
#   '1100': 1,
#   '1101': 5,
#   '1110': 8,
#   '1111': 6},
#  {'0000': 513,
#   '0001': 363,
#   '0010': 421,
#   '0011': 256,
#   '0100': 343,
#   '0101': 232,
#   '0110': 228,
#   '0111': 123,
#   '1000': 371,
#   '1001': 187,
#   '1010': 225,
#   '1011': 121,
#   '1100': 245,
#   '1101': 122,
#   '1110': 113,
#   '1111': 137},
#  {'0000': 203,
#   '0001': 216,
#   '0010': 218,
#   '0011': 274,
#   '0100': 233,
#   '0101': 266,
#   '0110': 266,
#   '0111': 244,
#   '1000': 201,
#   '1001': 284,
#   '1010': 263,
#   '1011': 263,
#   '1100': 268,
#   '1101': 281,
#   '1110': 256,
#   '1111': 264},
#  {'0000': 3785,
#   '0001': 48,
#   '0010': 42,
#   '0011': 3,
#   '0100': 44,
#   '0101': 2,
#   '0110': 3,
#   '0111': 2,
#   '1000': 50,
#   '1001': 6,
#   '1010': 3,
#   '1011': 2,
#   '1100': 3,
#   '1101': 5,
#   '1110': 2},
#  {'0000': 552,
#   '0001': 363,
#   '0010': 394,
#   '0011': 223,
#   '0100': 424,
#   '0101': 227,
#   '0110': 231,
#   '0111': 113,
#   '1000': 433,
#   '1001': 222,
#   '1010': 214,
#   '1011': 90,
#   '1100': 233,
#   '1101': 131,
#   '1110': 100,
#   '1111': 50},
#  {'0000': 130,
#   '0001': 165,
#   '0010': 142,
#   '0011': 214,
#   '0100': 163,
#   '0101': 217,
#   '0110': 231,
#   '0111': 316,
#   '1000': 184,
#   '1001': 200,
#   '1010': 230,
#   '1011': 320,
#   '1100': 264,
#   '1101': 291,
#   '1110': 330,
#   '1111': 603},
#  {'0000': 3559,
#   '0001': 99,
#   '0010': 105,
#   '0011': 11,
#   '0100': 75,
#   '0101': 6,
#   '0110': 11,
#   '0111': 3,
#   '1000': 102,
#   '1001': 10,
#   '1010': 9,
#   '1011': 1,
#   '1100': 6,
#   '1110': 3},
#  {'0000': 443,
#   '0001': 340,
#   '0010': 326,
#   '0011': 254,
#   '0100': 367,
#   '0101': 221,
#   '0110': 228,
#   '0111': 169,
#   '1000': 356,
#   '1001': 261,
#   '1010': 229,
#   '1011': 172,
#   '1100': 248,
#   '1101': 137,
#   '1110': 157,
#   '1111': 92},
#  {'0000': 84,
#   '0001': 109,
#   '0010': 123,
#   '0011': 182,
#   '0100': 115,
#   '0101': 186,
#   '0110': 197,
#   '0111': 339,
#   '1000': 107,
#   '1001': 191,
#   '1010': 197,
#   '1011': 377,
#   '1100': 206,
#   '1101': 391,
#   '1110': 370,
#   '1111': 826},
#  {'0000': 3481,
#   '0001': 112,
#   '0010': 120,
#   '0011': 3,
#   '0100': 125,
#   '0101': 6,
#   '0110': 8,
#   '0111': 1,
#   '1000': 129,
#   '1001': 5,
#   '1010': 8,
#   '1100': 2},
#  {'0000': 263,
#   '0001': 249,
#   '0010': 233,
#   '0011': 254,
#   '0100': 262,
#   '0101': 249,
#   '0110': 267,
#   '0111': 216,
#   '1000': 251,
#   '1001': 264,
#   '1010': 232,
#   '1011': 270,
#   '1100': 281,
#   '1101': 224,
#   '1110': 253,
#   '1111': 232},
#  {'0000': 78,
#   '0001': 125,
#   '0010': 132,
#   '0011': 182,
#   '0100': 123,
#   '0101': 241,
#   '0110': 202,
#   '0111': 396,
#   '1000': 129,
#   '1001': 228,
#   '1010': 208,
#   '1011': 361,
#   '1100': 223,
#   '1101': 359,
#   '1110': 393,
#   '1111': 620},
#  {'0000': 3699,
#   '0001': 72,
#   '0010': 71,
#   '0011': 2,
#   '0100': 68,
#   '0101': 1,
#   '1000': 78,
#   '1001': 3,
#   '1010': 4,
#   '1100': 2}]

# %%
from helper import combine_twirled_data, combine_mag_data

twirled_data = combine_twirled_data(quasi_probs, num_twirls)
mag_data = combine_mag_data(twirled_data)

# %%
mag_vec_data = {"x": [], "y": [], "z": []}

for tidx, _ in enumerate(t_range):
    mag_vec_data["x"].append(sum([1-2*sum([value for key, value in mag_data["x"][tidx].items() 
        if key[num_spins-qidx-1] == '1']) for qidx, _ in enumerate(my_layout)])/num_spins)
    mag_vec_data["y"].append(sum([1-2*sum([value for key, value in mag_data["y"][tidx].items() 
        if key[num_spins-qidx-1] == '1']) for qidx, _ in enumerate(my_layout)])/num_spins)
    mag_vec_data["z"].append(sum([1-2*sum([value for key, value in mag_data['z'][tidx].items() 
        if key[num_spins-qidx-1] == '1']) for qidx, _ in enumerate(my_layout)])/num_spins)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb Cell 44 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> mag_vec_data = {"x": [], "y": [], "z": []}
#       <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=2'>3</a> for tidx, _ in enumerate(t_range):
# ----> <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=3'>4</a>     mag_vec_data["x"].append(sum([1-2*sum([value for key, value in mag_data["x"][tidx].items()
#       <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=4'>5</a>         if key[num_spins-qidx-1] == '1']) for qidx, _ in enumerate(my_layout)])/num_spins)
#       <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=5'>6</a>     mag_vec_data["y"].append(sum([1-2*sum([value for key, value in mag_data["y"][tidx].items()
#       <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=6'>7</a>         if key[num_spins-qidx-1] == '1']) for qidx, _ in enumerate(my_layout)])/num_spins)
#       <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=7'>8</a>     mag_vec_data["z"].append(sum([1-2*sum([value for key, value in mag_data['z'][tidx].items()
#       <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=8'>9</a>         if key[num_spins-qidx-1] == '1']) for qidx, _ in enumerate(my_layout)])/num_spins)
#
# /Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb Cell 44 in <listcomp>(.0)
#       <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> mag_vec_data = {"x": [], "y": [], "z": []}
#       <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=2'>3</a> for tidx, _ in enumerate(t_range):
# ----> <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=3'>4</a>     mag_vec_data["x"].append(sum([1-2*sum([value for key, value in mag_data["x"][tidx].items()
#       <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=4'>5</a>         if key[num_spins-qidx-1] == '1']) for qidx, _ in enumerate(my_layout)])/num_spins)
#       <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=5'>6</a>     mag_vec_data["y"].append(sum([1-2*sum([value for key, value in mag_data["y"][tidx].items()
#       <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=6'>7</a>         if key[num_spins-qidx-1] == '1']) for qidx, _ in enumerate(my_layout)])/num_spins)
#       <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=7'>8</a>     mag_vec_data["z"].append(sum([1-2*sum([value for key, value in mag_data['z'][tidx].items()
#       <a href='vscode-notebook-cell:/Users/nick/Documents/codebase/qiskit-research/docs/getting_started.ipynb#X61sZmlsZQ%3D%3D?line=8'>9</a>         if key[num_spins-qidx-1] == '1']) for qidx, _ in enumerate(my_layout)])/num_spins)
#
# IndexError: list index out of range

# %%
1-2*sum([value for key, value in mag_data['x'][0].items() if key[0] == '1'])
# Out:
# 0.0057870370370369795

# %%
1-2*sum([value for key, value in mag_data['x'][0].items() if key[0] == '1'])
# Out:
# 0.0057870370370369795

# %%
mag_data['y'][0]
# Out:
# {'0000': 0.07758887527104044,
#  '0001': 0.05634074551563922,
#  '0010': 0.06454907113330724,
#  '0011': 0.0710405507090165,
#  '0100': 0.05739981342824843,
#  '0101': 0.04645241406430874,
#  '0110': 0.0666210844164486,
#  '0111': 0.06455440313394849,
#  '1000': 0.07746464574606353,
#  '1001': 0.056628164983932826,
#  '1010': 0.06127298423984416,
#  '1011': 0.06798452983637336,
#  '1100': 0.0571967378485921,
#  '1101': 0.04440935851934864,
#  '1110': 0.06274734268462719,
#  '1111': 0.06774927846926045}

# %%
sum([value for key, value in mag_data['z'][0].items() if key[0] == '0'])
# Out:
# 0.5081718050468051

# %%
pnts = [mag_vec_data["x"], mag_vec_data["y"], mag_vec_data["z"]]

plt.rcParams["figure.figsize"] = [7, 7]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
u, v = np.mgrid[0:2 * np.pi:30j, 0:np.pi:20j]
x = np.cos(u) * np.sin(v)
y = np.sin(u) * np.sin(v)
z = np.cos(v)
ax.plot_surface(x, y, z, cmap=plt.cm.YlGnBu_r, alpha=0.25, antialiased=False)
ax.plot(pnts[0], pnts[1], pnts[2], color='r', lw=4.0, label='Exact')
ax.set_title('Net Magnetization', fontsize=20)
plt.axis('off')
plt.show()

# %%
np.sqrt(np.asarray(mag_vec_data["x"])**2 + np.asarray(mag_vec_data["y"])**2 + np.asarray(mag_vec_data["z"])**2)
# Out:
# array([0.0285354 , 0.00274777, 0.0109113 , 0.29268465, 0.72757383,
#        1.07331159, 0.59410998, 0.17399916, 0.45659739, 0.45112942,
#        0.4032523 , 0.26846348, 0.09293965, 0.03681676, 0.04706605,
#        0.12518976, 0.11794225, 0.06463709, 0.24247813, 0.29876969,
#        0.26437788, 0.16712345, 0.05599567, 0.18054433, 0.27945628,
#        0.24290021, 0.19853288, 0.09173635, 0.03721072, 0.10863885,
#        0.06783316, 0.03843339, 0.05512337, 0.22720535, 0.40337242,
#        0.35778195, 0.19778537, 0.06309348, 0.03773956, 0.0158754 ,
#        0.07812164, 0.18993381, 0.24316578, 0.14114347, 0.10471379,
#        0.27045444, 0.23397111, 0.14010613, 0.05040062, 0.11859938,
#        0.23666704])

# %%
# collect quasi-probabilities from different Pauli twirls
quasi_probs_twirled = []
for time_idx in range(num_time_steps):
    quasi_prob_twirled = {}
    for twidx in range(num_twirls):
        for key in quasi_probs[time_idx * num_twirls + twidx].keys():
            try:
                quasi_prob_twirled[key] += (
                    quasi_probs[time_idx * num_twirls + twidx][key] / num_twirls
                )
            except:
                quasi_prob_twirled[key] = (
                    quasi_probs[time_idx * num_twirls + twidx][key] / num_twirls
                )

    quasi_probs_twirled.append(quasi_prob_twirled)

# %%
# separate list of dicts into dict of lists
quasi_probs_dict = {}
for time_step in quasi_probs_twirled:
    for key in time_step.keys():
        try:
            quasi_probs_dict[key].append(time_step[key])
        except:
            quasi_probs_dict[key] = [time_step[key]]

# %%
# plot results
fig, ax = plt.subplots(figsize=(12, 4))
for key in quasi_probs_dict.keys():
    ax.plot(t_range, quasi_probs_dict[key], lw=2, label=key)
ax.set_xlabel("time step (arb)")
ax.set_ylabel("quasi-probability")
ax.legend(loc=4)
plt.show()

# %%
from helper import exact_magnetization
mags = exact_magnetization(U_ham, param_bind, t_range)

# %%
pnts = mags

plt.rcParams["figure.figsize"] = [7, 7]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
u, v = np.mgrid[0:2 * np.pi:30j, 0:np.pi:20j]
x = np.cos(u) * np.sin(v)
y = np.sin(u) * np.sin(v)
z = np.cos(v)
ax.plot_surface(x, y, z, cmap=plt.cm.YlGnBu_r, alpha=0.25, antialiased=False)
ax.plot(pnts[0], pnts[1], pnts[2], color='r', lw=4.0, label='Exact')
ax.set_title('Net Magnetization', fontsize=20)
plt.axis('off')
plt.show()

# %%
pnts[2]
# Out:
# [1.0,
#  0.9235467170055532,
#  0.730399937171692,
#  0.49419000972509536,
#  0.27258704772955594,
#  0.098870431486561,
#  -0.0028156868857218686,
#  -0.01729625383906728,
#  0.05669609287677102,
#  0.20341453842826102,
#  0.37607775294360335,
#  0.49737834719857865,
#  0.5059412726858492,
#  0.4022146267488975,
#  0.2295790076599816,
#  0.02343765434472965,
#  -0.1983852623289487,
#  -0.4118493457679716,
#  -0.5809096019607336,
#  -0.6702671327082702,
#  -0.6573519185621073,
#  -0.5512236190117964,
#  -0.4046480143500928,
#  -0.2824900339234368,
#  -0.21248862766364313,
#  -0.18747186176678823,
#  -0.20856708188482506,
#  -0.2936555119604575,
#  -0.4428933563457772,
#  -0.6208875611623447,
#  -0.7720659350122938,
#  -0.8418441766629977,
#  -0.8005053255479415,
#  -0.6653627782023335,
#  -0.48560741501289023,
#  -0.2963212413538924,
#  -0.10794461926283708,
#  0.057231925205813855,
#  0.15316439111284694,
#  0.14948878534040788,
#  0.06249822453154377,
#  -0.05691861410523799,
#  -0.14924187300381195,
#  -0.1698373316220843,
#  -0.11222672460260778,
#  -0.004158389551973875,
#  0.1316789631270217,
#  0.2951991536282461,
#  0.47491151284450916,
#  0.6247709308090977,
#  0.6981334656884118]
